# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --num-walks 10 --walk-length 10 --p 2 --q 2 --embedding_sizes 2 5 10 20
# Out:
# Loading dataset: CA
# Graph construction completed in 0.63 seconds
# PyG Graph: 20433 nodes, 204330 edges
#
# === Running Baseline Models ===
#
# === Running Node2Vec Grid Search (includes DeepWalk) ===
#
# --- Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:30<00:00,  1.02s/it, Loss=0.9983, Best=0.9983]
# DeepWalk training completed in 30.73 seconds
# Full pipeline completed in 30.74 seconds
# DeepWalk Grid Search:  25%|██▌       | 1/4 [01:55<05:47, 115.92s/it, Testing=vec_size=5]
# Training DeepWalk with vector_size=5
# DeepWalk Training: 100%|██████████| 30/30 [00:29<00:00,  1.02it/s, Loss=0.8966, Best=0.8965]
# DeepWalk training completed in 29.32 seconds
# Full pipeline completed in 29.32 seconds
# DeepWalk Grid Search:  50%|█████     | 2/4 [04:19<04:24, 132.17s/it, Testing=vec_size=10]
# Training DeepWalk with vector_size=10
# DeepWalk Training: 100%|██████████| 30/30 [00:28<00:00,  1.05it/s, Loss=0.8388, Best=0.8388]
# DeepWalk training completed in 28.58 seconds
# Full pipeline completed in 28.58 seconds
# DeepWalk Grid Search:  75%|███████▌  | 3/4 [07:32<02:39, 159.75s/it, Testing=vec_size=20]
# Training DeepWalk with vector_size=20
# DeepWalk Training: 100%|██████████| 30/30 [00:28<00:00,  1.07it/s, Loss=0.7961, Best=0.7960]
# DeepWalk training completed in 28.16 seconds
# Full pipeline completed in 28.16 seconds
# DeepWalk Grid Search: 100%|██████████| 4/4 [12:22<00:00, 185.62s/it, Testing=vec_size=20]
# [DeepWalk] Best embedding size: 5 with r2: 0.818
#
# --- Testing Node2Vec (p=1, q=2) ---
# Node2Vec (p=1, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1, q=2) with vector_size=2
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it, Loss=1.0054, Best=1.0054]
# Node2Vec (p=1, q=2) training completed in 34.84 seconds
# Full pipeline completed in 34.84 seconds
# Node2Vec (p=1, q=2) Grid Search:  25%|██▌       | 1/4 [01:59<05:59, 119.72s/it, Testing=vec_size=5]
# Training Node2Vec (p=1, q=2) with vector_size=5
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:31<00:00,  1.06s/it, Loss=0.9008, Best=0.9000]
# Node2Vec (p=1, q=2) training completed in 31.81 seconds
# Full pipeline completed in 31.81 seconds
# Node2Vec (p=1, q=2) Grid Search:  50%|█████     | 2/4 [04:26<04:31, 135.67s/it, Testing=vec_size=10]
# Training Node2Vec (p=1, q=2) with vector_size=10
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:30<00:00,  1.03s/it, Loss=0.8406, Best=0.8406]
# Node2Vec (p=1, q=2) training completed in 30.82 seconds
# Full pipeline completed in 30.82 seconds
# Node2Vec (p=1, q=2) Grid Search:  75%|███████▌  | 3/4 [07:42<02:42, 162.98s/it, Testing=vec_size=20]
# Training Node2Vec (p=1, q=2) with vector_size=20
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:30<00:00,  1.02s/it, Loss=0.7976, Best=0.7975]
# Node2Vec (p=1, q=2) training completed in 30.59 seconds
# Full pipeline completed in 30.61 seconds
# Node2Vec (p=1, q=2) Grid Search: 100%|██████████| 4/4 [12:37<00:00, 189.39s/it, Testing=vec_size=20]
# [Node2Vec (p=1, q=2)] Best embedding size: 5 with r2: 0.820
#
# --- Testing Node2Vec (p=2, q=1) ---
# Node2Vec (p=2, q=1) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=1) with vector_size=2
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:34<00:00,  1.13s/it, Loss=0.9983, Best=0.9983]
# Node2Vec (p=2, q=1) training completed in 34.05 seconds
# Full pipeline completed in 34.07 seconds
# Node2Vec (p=2, q=1) Grid Search:  25%|██▌       | 1/4 [01:58<05:55, 118.48s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=1) with vector_size=5
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:31<00:00,  1.03s/it, Loss=0.8967, Best=0.8966]
# Node2Vec (p=2, q=1) training completed in 31.02 seconds
# Full pipeline completed in 31.02 seconds
# Node2Vec (p=2, q=1) Grid Search:  50%|█████     | 2/4 [04:23<04:27, 133.84s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=1) with vector_size=10
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:29<00:00,  1.00it/s, Loss=0.8385, Best=0.8385]
# Node2Vec (p=2, q=1) training completed in 30.01 seconds
# Full pipeline completed in 30.02 seconds
# Node2Vec (p=2, q=1) Grid Search:  75%|███████▌  | 3/4 [07:36<02:41, 161.14s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=1) with vector_size=20
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:29<00:00,  1.00it/s, Loss=0.7960, Best=0.7960]
# Node2Vec (p=2, q=1) training completed in 29.92 seconds
# Full pipeline completed in 29.93 seconds
# Node2Vec (p=2, q=1) Grid Search: 100%|██████████| 4/4 [12:30<00:00, 187.50s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=1)] Best embedding size: 5 with r2: 0.819
#
# --- Testing Node2Vec (p=2, q=2) ---
# Node2Vec (p=2, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=2) with vector_size=2
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it, Loss=1.0045, Best=1.0038]
# Node2Vec (p=2, q=2) training completed in 34.81 seconds
# Full pipeline completed in 34.82 seconds
# Node2Vec (p=2, q=2) Grid Search:  25%|██▌       | 1/4 [02:02<06:07, 122.43s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=2) with vector_size=5
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:31<00:00,  1.06s/it, Loss=0.9001, Best=0.8998]
# Node2Vec (p=2, q=2) training completed in 31.95 seconds
# Full pipeline completed in 31.95 seconds
# Node2Vec (p=2, q=2) Grid Search:  50%|█████     | 2/4 [04:34<04:39, 139.96s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=2) with vector_size=10
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:32<00:00,  1.08s/it, Loss=0.8408, Best=0.8408]
# Node2Vec (p=2, q=2) training completed in 32.44 seconds
# Full pipeline completed in 32.45 seconds
# Node2Vec (p=2, q=2) Grid Search:  75%|███████▌  | 3/4 [07:56<02:48, 168.27s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=2) with vector_size=20
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:31<00:00,  1.04s/it, Loss=0.7975, Best=0.7974]
# Node2Vec (p=2, q=2) training completed in 31.08 seconds
# Full pipeline completed in 31.10 seconds
# Node2Vec (p=2, q=2) Grid Search: 100%|██████████| 4/4 [12:58<00:00, 194.61s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=2)] Best embedding size: 5 with r2: 0.818
#
# === Experiment Summary ===
# Saved results to results-gpu/CA/final_results.csv
# Total experiment time: 3205.78 seconds
# Timing breakdown saved to results-gpu/CA/experiment_timing.csv
# CPU times: total: 51min 37s
# Wall time: 53min 36s

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 10 --walk-length 10 --p 2 --q 2 --embedding_sizes 2 5 10 20
# Out:
# Loading dataset: MHD
# Graph construction completed in 2.67 seconds
# PyG Graph: 10000 nodes, 85959 edges
#
# === Running Baseline Models ===
#
# === Running Node2Vec Grid Search (includes DeepWalk) ===
#
# --- Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:17<00:00,  1.73it/s, Loss=0.7861, Best=0.7861]
# DeepWalk training completed in 17.37 seconds
# Full pipeline completed in 17.37 seconds
# DeepWalk Grid Search:  25%|██▌       | 1/4 [00:48<02:24, 48.33s/it, Testing=vec_size=5]
# Training DeepWalk with vector_size=5
# DeepWalk Training: 100%|██████████| 30/30 [00:14<00:00,  2.07it/s, Loss=0.7548, Best=0.7548]
# DeepWalk training completed in 14.47 seconds
# Full pipeline completed in 14.48 seconds
# DeepWalk Grid Search:  50%|█████     | 2/4 [01:47<01:49, 54.60s/it, Testing=vec_size=10]
# Training DeepWalk with vector_size=10
# DeepWalk Training: 100%|██████████| 30/30 [00:13<00:00,  2.26it/s, Loss=0.7383, Best=0.7380]
# DeepWalk training completed in 13.31 seconds
# Full pipeline completed in 13.31 seconds
# DeepWalk Grid Search:  75%|███████▌  | 3/4 [03:09<01:07, 67.13s/it, Testing=vec_size=20]
# Training DeepWalk with vector_size=20
# DeepWalk Training: 100%|██████████| 30/30 [00:13<00:00,  2.17it/s, Loss=0.7267, Best=0.7265]
# DeepWalk training completed in 13.86 seconds
# Full pipeline completed in 13.87 seconds
# DeepWalk Grid Search: 100%|██████████| 4/4 [05:15<00:00, 78.86s/it, Testing=vec_size=20]
# [DeepWalk] Best embedding size: 2 with r2: 0.823
#
# --- Testing Node2Vec (p=1, q=2) ---
# Node2Vec (p=1, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1, q=2) with vector_size=2
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:17<00:00,  1.74it/s, Loss=0.7871, Best=0.7868]
# Node2Vec (p=1, q=2) training completed in 17.30 seconds
# Full pipeline completed in 17.30 seconds
# Node2Vec (p=1, q=2) Grid Search:  25%|██▌       | 1/4 [00:48<02:24, 48.06s/it, Testing=vec_size=5]
# Training Node2Vec (p=1, q=2) with vector_size=5
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:16<00:00,  1.83it/s, Loss=0.7550, Best=0.7550]
# Node2Vec (p=1, q=2) training completed in 16.44 seconds
# Full pipeline completed in 16.45 seconds
# Node2Vec (p=1, q=2) Grid Search:  50%|█████     | 2/4 [01:49<01:51, 55.68s/it, Testing=vec_size=10]
# Training Node2Vec (p=1, q=2) with vector_size=10
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:14<00:00,  2.04it/s, Loss=0.7384, Best=0.7384]
# Node2Vec (p=1, q=2) training completed in 14.72 seconds
# Full pipeline completed in 14.73 seconds
# Node2Vec (p=1, q=2) Grid Search:  75%|███████▌  | 3/4 [03:10<01:07, 67.54s/it, Testing=vec_size=20]
# Training Node2Vec (p=1, q=2) with vector_size=20
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:14<00:00,  2.10it/s, Loss=0.7269, Best=0.7269]
# Node2Vec (p=1, q=2) training completed in 14.34 seconds
# Full pipeline completed in 14.34 seconds
# Node2Vec (p=1, q=2) Grid Search: 100%|██████████| 4/4 [05:15<00:00, 78.84s/it, Testing=vec_size=20]
# [Node2Vec (p=1, q=2)] Best embedding size: 2 with r2: 0.821
#
# --- Testing Node2Vec (p=2, q=1) ---
# Node2Vec (p=2, q=1) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=1) with vector_size=2
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:17<00:00,  1.69it/s, Loss=0.7852, Best=0.7852]
# Node2Vec (p=2, q=1) training completed in 17.73 seconds
# Full pipeline completed in 17.73 seconds
# Node2Vec (p=2, q=1) Grid Search:  25%|██▌       | 1/4 [00:48<02:24, 48.18s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=1) with vector_size=5
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:16<00:00,  1.87it/s, Loss=0.7542, Best=0.7542]
# Node2Vec (p=2, q=1) training completed in 16.09 seconds
# Full pipeline completed in 16.14 seconds
# Node2Vec (p=2, q=1) Grid Search:  50%|█████     | 2/4 [01:48<01:50, 55.33s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=1) with vector_size=10
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:14<00:00,  2.05it/s, Loss=0.7376, Best=0.7376]
# Node2Vec (p=2, q=1) training completed in 14.62 seconds
# Full pipeline completed in 14.63 seconds
# Node2Vec (p=2, q=1) Grid Search:  75%|███████▌  | 3/4 [03:09<01:07, 67.16s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=1) with vector_size=20
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:14<00:00,  2.10it/s, Loss=0.7263, Best=0.7263]
# Node2Vec (p=2, q=1) training completed in 14.33 seconds
# Full pipeline completed in 14.33 seconds
# Node2Vec (p=2, q=1) Grid Search: 100%|██████████| 4/4 [05:15<00:00, 78.80s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=1)] Best embedding size: 2 with r2: 0.823
#
# --- Testing Node2Vec (p=2, q=2) ---
# Node2Vec (p=2, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=2) with vector_size=2
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:17<00:00,  1.68it/s, Loss=0.7874, Best=0.7874]
# Node2Vec (p=2, q=2) training completed in 17.90 seconds
# Full pipeline completed in 17.90 seconds
# Node2Vec (p=2, q=2) Grid Search:  25%|██▌       | 1/4 [00:48<02:26, 48.68s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=2) with vector_size=5
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:16<00:00,  1.81it/s, Loss=0.7550, Best=0.7550]
# Node2Vec (p=2, q=2) training completed in 16.63 seconds
# Full pipeline completed in 16.63 seconds
# Node2Vec (p=2, q=2) Grid Search:  50%|█████     | 2/4 [01:49<01:52, 56.08s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=2) with vector_size=10
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:14<00:00,  2.04it/s, Loss=0.7381, Best=0.7381]
# Node2Vec (p=2, q=2) training completed in 14.75 seconds
# Full pipeline completed in 14.77 seconds
# Node2Vec (p=2, q=2) Grid Search:  75%|███████▌  | 3/4 [03:11<01:07, 67.72s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=2) with vector_size=20
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:14<00:00,  2.06it/s, Loss=0.7263, Best=0.7263]
# Node2Vec (p=2, q=2) training completed in 14.61 seconds
# Full pipeline completed in 14.61 seconds
# Node2Vec (p=2, q=2) Grid Search: 100%|██████████| 4/4 [05:17<00:00, 79.27s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=2)] Best embedding size: 10 with r2: 0.819
#
# === Experiment Summary ===
# Saved results to results-gpu/MHD/final_results.csv
# Total experiment time: 1341.41 seconds
# Timing breakdown saved to results-gpu/MHD/experiment_timing.csv
# CPU times: total: 21min 40s
# Wall time: 22min 21s

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter
import os

def compare_models(dataset_name, use_rmse=False, res_file_name="final_results.csv"):
    """
    Side-by-side comparison plots (R² and MSE_log or RMSE) for a dataset.
    - Highlights the single best model across all methods with a red star.
    - Adds dataset name to each subplot.
    - Applies y-axis limits to emphasize differences.
    - If use_rmse=True, plots RMSE in millions; otherwise plots MSE_log.
    """
    # Load results
    file_path = f"results-gpu/{dataset_name}/{res_file_name}"
    df = pd.read_csv(file_path)

    # Categorize models
    def categorize(model):
        if "DeepWalk" in model:
            return "DeepWalk"
        elif "Node2Vec" in model:
            return "Node2Vec"
        else:
            return "Raw"

    # df["Method"] = df["Model"].apply(categorize)
    # df["BaseModel"] = df["Model"].apply(lambda x: x.split(" ")[0])

    # Pivot to align bars by BaseModel for each Type
    order_types = ["Raw", "DeepWalk", "Node2Vec"]
    r2_pivot = df.pivot_table(index="BaseModel", columns="Method", values="R2", aggfunc="mean").reindex(columns=order_types)
    mselog_pivot = df.pivot_table(index="BaseModel", columns="Method", values="MSE_log", aggfunc="mean").reindex(columns=order_types)
    rmse_pivot = df.pivot_table(index="BaseModel", columns="Method", values="RMSE", aggfunc="mean").reindex(columns=order_types)

    # Base models for x-axis
    models = r2_pivot.index.tolist()
    x = np.arange(len(models))
    bar_width = 0.25

    fig, axs = plt.subplots(1, 2, figsize=(14, 6))

    # -------------------------------
    # Plot 1: R² comparison
    # -------------------------------
    all_r2_bars = []
    bar_positions = []
    for i, t in enumerate(order_types):
        vals = r2_pivot[t].values
        positions = x + i*bar_width - bar_width
        axs[0].bar(positions, vals, width=bar_width, label=t)
        all_r2_bars.extend(vals)
        bar_positions.extend(positions)

    # Highlight single best R² (max)
    best_idx = np.nanargmax(all_r2_bars)
    axs[0].scatter(bar_positions[best_idx], all_r2_bars[best_idx],
                   color="red", zorder=5, s=100, marker="*")

    axs[0].set_title("R² Score Comparison")
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(models)#, rotation=45)
    axs[0].set_ylabel("R²")
    axs[0].legend()

    # y-axis limit
    r2_mean = np.nanmean(all_r2_bars)
    axs[0].set_ylim(0.6, 0.92)

    axs[0].text(0.5, 0.05, f"Dataset: {dataset_name}", transform=axs[0].transAxes,
                fontsize=10, ha="center", va="bottom",
                bbox=dict(boxstyle="round", fc="white", alpha=0.6))

    # -------------------------------
    # Plot 2: MSE_log or RMSE comparison
    # -------------------------------
    if use_rmse:
        metric_name = "RMSE"
        pivot = rmse_pivot
        # formatter
        def thousands(x, pos): return f"{x/1e3:.1f}K"
        def millions(x, pos): return f"{x/1e6:.1f}M"
        def billions(x, pos): return f"{x/1e9:.1f}B"

        if dataset_name == 'CA':
            axs[1].yaxis.set_major_formatter(FuncFormatter(thousands))
        else:
            axs[1].yaxis.set_major_formatter(FuncFormatter(billions))
    else:
        metric_name = "MSE (log-scale)"
        pivot = mselog_pivot

    all_metric_bars = []
    bar_positions_metric = []
    for i, t in enumerate(order_types):
        vals = pivot[t].values
        positions = x + i*bar_width - bar_width
        axs[1].bar(positions, vals, width=bar_width, label=t)
        all_metric_bars.extend(vals)
        bar_positions_metric.extend(positions)

    # Highlight single best (min) for RMSE or MSE_log
    best_idx = np.nanargmin(all_metric_bars)
    axs[1].scatter(bar_positions_metric[best_idx], all_metric_bars[best_idx],
                   color="red", zorder=5, s=100, marker="*")

    axs[1].set_title(f"{metric_name} Comparison")
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(models)#, rotation=45)
    axs[1].set_ylabel(metric_name)
    axs[1].legend()

    # y-axis limit
    y_mean = np.nanmean(all_metric_bars)
    axs[1].set_ylim(y_mean * 0.7, y_mean * 1.4)

    axs[1].text(0.5, 0.05, f"Dataset: {dataset_name}", transform=axs[1].transAxes,
                fontsize=10, ha="center", va="bottom",
                bbox=dict(boxstyle="round", fc="white", alpha=0.6))

    plt.tight_layout()

    # Save figure
    out_path = f"results-gpu/{dataset_name}/model_comparison.png" if not use_rmse \
               else f"results-gpu/{dataset_name}/model_comparison_rmse.png"
    os.makedirs(f"results-gpu/{dataset_name}", exist_ok=True)
    plt.savefig(out_path, dpi=300)
    plt.show()
    print(f"Comparison plot saved to {out_path}")


# Example runs
compare_models("CA", True, "final_results.csv")  # R² + RMSE (in millions)
compare_models("MHD", True, "final_results.csv")
# Out:
# Comparison plot saved to results-gpu/CA/model_comparison_rmse.png
# Comparison plot saved to results-gpu/MHD/model_comparison_rmse.png
