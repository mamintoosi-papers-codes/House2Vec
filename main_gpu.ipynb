# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --graph-method threshold --embedding-sizes 2 4 8
# Out:
# Loading dataset: CA
# KNN with Threshold graph construction completed in 0.85 seconds
# PyG Graph: 20433 nodes, 204330 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/CA/baseline_results.csv
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 40/40 [01:09<00:00,  1.74s/it, Loss=0.9789, Best=0.9788]
# Node2Vec (p=0.5, q=0.5) training completed in 69.62 seconds
# Full pipeline completed in 69.63 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [01:41<03:22, 101.16s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# ...

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method threshold --embedding-sizes  2 4 8
# Out:
# Loading dataset: MHD
# KNN with Threshold graph construction completed in 2.63 seconds
# PyG Graph: 10000 nodes, 85959 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/MHD/baseline_results.csv
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 40/40 [00:36<00:00,  1.09it/s, Loss=0.7708, Best=0.7707]
# Node2Vec (p=0.5, q=0.5) training completed in 36.60 seconds
# Full pipeline completed in 36.61 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [00:46<01:32, 46.45s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# ...

# %%
# %%time
# %run main_pyg.py --dataset CA --graph-method threshold --embedding-sizes  2 4 8

# batch_size=4096
# Out:
# Loading dataset: CA
# KNN with Threshold graph construction completed in 0.73 seconds
# PyG Graph: 20433 nodes, 204330 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/CA/baseline_results.csv
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 40/40 [01:08<00:00,  1.71s/it, Loss=1.0501, Best=1.0501]
# Node2Vec (p=0.5, q=0.5) training completed in 68.31 seconds
# Full pipeline completed in 68.32 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [01:39<03:19, 99.68s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# ...

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method threshold --embedding-sizes  2 4 8

# batch_size=4096
# Out:
# Loading dataset: MHD
# KNN with Threshold graph construction completed in 11.56 seconds
# PyG Graph: 44781 nodes, 377631 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/MHD/baseline_results.csv
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 40/40 [02:50<00:00,  4.25s/it, Loss=0.7558, Best=0.7558]
# Node2Vec (p=0.5, q=0.5) training completed in 170.08 seconds
# Full pipeline completed in 170.11 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [03:33<07:06, 213.27s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# ...

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method threshold --embedding-sizes  2 4 8
# Out:
# Loading dataset: MHD
# KNN with Threshold graph construction completed in 5.56 seconds
# PyG Graph: 20000 nodes, 171697 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/MHD/baseline_results.csv
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 40/40 [01:11<00:00,  1.78s/it, Loss=0.7588, Best=0.7587]
# Node2Vec (p=0.5, q=0.5) training completed in 71.30 seconds
# Full pipeline completed in 71.32 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [01:30<03:01, 90.66s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# ...

# %%
# %%time
# %run main_pyg.py --dataset CA --num-walks 3 --walk-length 10 --p 2 --q 1 --embedding_sizes 2 5 --quiet

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method hybrid --embedding-sizes 2 4 16

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 5 --walk-length 15 --p 2 --q 1 --embedding_sizes 2 5 --quiet

# %%
# from utils_pyg import compare_models
# compare_models("CA", 'R2')
# compare_models("CA", 'RMSE')
# compare_models("CA", 'MSE_log')
# compare_models("MHD", 'R2') 
# compare_models("MHD", 'RMSE')
# compare_models("MHD", 'MSE_log')
