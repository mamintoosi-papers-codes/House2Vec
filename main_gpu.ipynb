# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --graph-method threshold --embedding-sizes 2 4 8
# Out:
# Loading dataset: CA
# KNN with Threshold graph construction completed in 0.79 seconds
# PyG Graph: 20433 nodes, 204330 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/CA/baseline_results.csv
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [01:03<00:00,  2.12s/it, Loss=0.9968, Best=0.9968]
# Node2Vec (p=0.5, q=0.5) training completed in 63.63 seconds
# Full pipeline completed in 63.64 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [01:35<03:11, 95.93s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:59<00:00,  1.98s/it, Loss=0.9161, Best=0.9161]
# Node2Vec (p=0.5, q=0.5) training completed in 59.45 seconds
# Full pipeline completed in 59.46 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  67%|██████▋   | 2/3 [03:14<01:37, 97.46s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=8
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:56<00:00,  1.89s/it, Loss=0.8516, Best=0.8516]
# Node2Vec (p=0.5, q=0.5) training completed in 56.73 seconds
# Full pipeline completed in 56.74 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search: 100%|██████████| 3/3 [05:04<00:00, 101.52s/it, Testing=vec_size=8]
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:564: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   master_df = pd.concat([master_df, new_results], ignore_index=True)
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:583: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   timing_master_df = pd.concat([timing_master_df, new_timing], ignore_index=True)
# [Node2Vec (p=0.5, q=0.5)] Best embedding size: 8 with r2: 0.781
#
# --- Strategy: dfs_local ---
# Parameters: p=0.5, q=1.0
# Testing Node2Vec (p=0.5, q=1.0) ---
# Node2Vec (p=0.5, q=1.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=2
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [01:10<00:00,  2.35s/it, Loss=0.9973, Best=0.9973]
# Node2Vec (p=0.5, q=1.0) training completed in 70.66 seconds
# Full pipeline completed in 70.67 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  33%|███▎      | 1/3 [01:43<03:26, 103.40s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=4
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [01:03<00:00,  2.11s/it, Loss=0.9161, Best=0.9161]
# Node2Vec (p=0.5, q=1.0) training completed in 63.33 seconds
# Full pipeline completed in 63.34 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  67%|██████▋   | 2/3 [03:24<01:42, 102.21s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=8
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:59<00:00,  1.98s/it, Loss=0.8524, Best=0.8524]
# Node2Vec (p=0.5, q=1.0) training completed in 59.54 seconds
# Full pipeline completed in 59.55 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search: 100%|██████████| 3/3 [05:16<00:00, 105.35s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=1.0)] Best embedding size: 8 with r2: 0.781
#
# --- Strategy: deepwalk ---
# Parameters: p=1.0, q=1.0
# Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [01:00<00:00,  2.02s/it, Loss=0.9968, Best=0.9968]
# DeepWalk training completed in 60.55 seconds
# Full pipeline completed in 60.56 seconds
# DeepWalk Grid Search:  33%|███▎      | 1/3 [01:32<03:05, 92.73s/it, Testing=vec_size=4]
# Training DeepWalk with vector_size=4
# DeepWalk Training: 100%|██████████| 30/30 [00:54<00:00,  1.80s/it, Loss=0.9161, Best=0.9161]
# DeepWalk training completed in 54.11 seconds
# Full pipeline completed in 54.11 seconds
# DeepWalk Grid Search:  67%|██████▋   | 2/3 [03:05<01:32, 92.58s/it, Testing=vec_size=8]
# Training DeepWalk with vector_size=8
# DeepWalk Training: 100%|██████████| 30/30 [00:50<00:00,  1.68s/it, Loss=0.8518, Best=0.8518]
# DeepWalk training completed in 50.34 seconds
# Full pipeline completed in 50.35 seconds
# DeepWalk Grid Search: 100%|██████████| 3/3 [04:47<00:00, 95.67s/it, Testing=vec_size=8]
# [DeepWalk] Best embedding size: 4 with r2: 0.781
#
# --- Strategy: bfs_local ---
# Parameters: p=1.0, q=0.5
# Testing Node2Vec (p=1.0, q=0.5) ---
# Node2Vec (p=1.0, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=2
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [01:01<00:00,  2.05s/it, Loss=0.9969, Best=0.9969]
# Node2Vec (p=1.0, q=0.5) training completed in 61.67 seconds
# Full pipeline completed in 61.68 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  33%|███▎      | 1/3 [01:33<03:06, 93.29s/it, Testing=vec_size=4]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=4
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:57<00:00,  1.92s/it, Loss=0.9155, Best=0.9155]
# Node2Vec (p=1.0, q=0.5) training completed in 57.69 seconds
# Full pipeline completed in 57.70 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  67%|██████▋   | 2/3 [03:09<01:34, 94.78s/it, Testing=vec_size=8]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=8
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:54<00:00,  1.82s/it, Loss=0.8520, Best=0.8520]
# Node2Vec (p=1.0, q=0.5) training completed in 54.49 seconds
# Full pipeline completed in 54.49 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search: 100%|██████████| 3/3 [04:55<00:00, 98.35s/it, Testing=vec_size=8]
# [Node2Vec (p=1.0, q=0.5)] Best embedding size: 8 with r2: 0.783
#
# === Experiment Summary ===
# Dataset: CA
# Graph type: KNN with Threshold
# Unified parameters applied to both datasets
# Saved results to results-gpu/CA/final_results.csv
# Best configurations comparison plot saved to results-gpu/CA/best_R2_comparison.png
# Selected best configurations for each method (based on R2):
#
# GradientBoosting:
#   Raw: R2=0.7894, R²=0.7894
#   DeepWalk: R2=0.7889, R²=0.7889
#   Node2Vec: p=1.0, q=0.5, R2=0.7951, R²=0.7951
#
# RandomForest:
#   Raw: R2=0.8392, R²=0.8392
#   DeepWalk: R2=0.8387, R²=0.8387
#   Node2Vec: p=0.5, q=0.5, R2=0.8402, R²=0.8402
# Best configurations comparison plot saved to results-gpu/CA/best_RMSE_comparison.png
# Selected best configurations for each method (based on RMSE):
#
# GradientBoosting:
#   Raw: RMSE=53889.3508, R²=0.7894
#   DeepWalk: RMSE=53945.1947, R²=0.7889
#   Node2Vec: p=1.0, q=0.5, RMSE=53145.8389, R²=0.7951
#
# RandomForest:
#   Raw: RMSE=47090.1269, R²=0.8392
#   DeepWalk: RMSE=47161.4193, R²=0.8387
#   Node2Vec: p=0.5, q=0.5, RMSE=46935.5394, R²=0.8402
# Best configurations comparison plot saved to results-gpu/CA/best_MSE_log_comparison.png
# Selected best configurations for each method (based on MSE_log):
#
# GradientBoosting:
#   Raw: MSE_log=0.0126, R²=0.7894
#   DeepWalk: MSE_log=0.0126, R²=0.7889
#   Node2Vec: p=0.5, q=0.5, MSE_log=0.0124, R²=0.7933
#
# RandomForest:
#   Raw: MSE_log=0.0095, R²=0.8392
#   DeepWalk: MSE_log=0.0095, R²=0.8387
#   Node2Vec: p=0.5, q=0.5, MSE_log=0.0092, R²=0.8402
# CPU times: total: 42min 35s
# Wall time: 24min 31s

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method threshold --embedding-sizes  2 4 8
# Out:
# Loading dataset: MHD
# KNN with Threshold graph construction completed in 2.56 seconds
# PyG Graph: 10000 nodes, 85959 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/MHD/baseline_results.csv
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:32<00:00,  1.08s/it, Loss=0.7862, Best=0.7862]
# Node2Vec (p=0.5, q=0.5) training completed in 32.50 seconds
# Full pipeline completed in 32.51 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [00:42<01:24, 42.21s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:30<00:00,  1.02s/it, Loss=0.7607, Best=0.7607]
# Node2Vec (p=0.5, q=0.5) training completed in 30.66 seconds
# Full pipeline completed in 30.67 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  67%|██████▋   | 2/3 [01:25<00:42, 43.00s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=8
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:27<00:00,  1.09it/s, Loss=0.7418, Best=0.7416]
# Node2Vec (p=0.5, q=0.5) training completed in 27.66 seconds
# Full pipeline completed in 27.67 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search: 100%|██████████| 3/3 [02:12<00:00, 44.21s/it, Testing=vec_size=8]
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:564: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   master_df = pd.concat([master_df, new_results], ignore_index=True)
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:583: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   timing_master_df = pd.concat([timing_master_df, new_timing], ignore_index=True)
# [Node2Vec (p=0.5, q=0.5)] Best embedding size: 2 with r2: 0.992
#
# --- Strategy: dfs_local ---
# Parameters: p=0.5, q=1.0
# Testing Node2Vec (p=0.5, q=1.0) ---
# Node2Vec (p=0.5, q=1.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=2
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:34<00:00,  1.15s/it, Loss=0.7863, Best=0.7863]
# Node2Vec (p=0.5, q=1.0) training completed in 34.52 seconds
# Full pipeline completed in 34.53 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  33%|███▎      | 1/3 [00:44<01:28, 44.23s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=4
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:34<00:00,  1.14s/it, Loss=0.7609, Best=0.7607]
# Node2Vec (p=0.5, q=1.0) training completed in 34.12 seconds
# Full pipeline completed in 34.13 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  67%|██████▋   | 2/3 [01:31<00:45, 45.82s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=8
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:29<00:00,  1.01it/s, Loss=0.7417, Best=0.7417]
# Node2Vec (p=0.5, q=1.0) training completed in 29.69 seconds
# Full pipeline completed in 29.70 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search: 100%|██████████| 3/3 [02:20<00:00, 46.67s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=1.0)] Best embedding size: 2 with r2: 0.992
#
# --- Strategy: deepwalk ---
# Parameters: p=1.0, q=1.0
# Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:29<00:00,  1.02it/s, Loss=0.7870, Best=0.7870]
# DeepWalk training completed in 29.42 seconds
# Full pipeline completed in 29.44 seconds
# DeepWalk Grid Search:  33%|███▎      | 1/3 [00:39<01:18, 39.10s/it, Testing=vec_size=4]
# Training DeepWalk with vector_size=4
# DeepWalk Training: 100%|██████████| 30/30 [00:27<00:00,  1.08it/s, Loss=0.7598, Best=0.7598]
# DeepWalk training completed in 27.82 seconds
# Full pipeline completed in 27.83 seconds
# DeepWalk Grid Search:  67%|██████▋   | 2/3 [01:19<00:40, 40.01s/it, Testing=vec_size=8]
# Training DeepWalk with vector_size=8
# DeepWalk Training: 100%|██████████| 30/30 [00:25<00:00,  1.19it/s, Loss=0.7418, Best=0.7418]
# DeepWalk training completed in 25.13 seconds
# Full pipeline completed in 25.13 seconds
# DeepWalk Grid Search: 100%|██████████| 3/3 [02:03<00:00, 41.33s/it, Testing=vec_size=8]
# [DeepWalk] Best embedding size: 2 with r2: 0.992
#
# --- Strategy: bfs_local ---
# Parameters: p=1.0, q=0.5
# Testing Node2Vec (p=1.0, q=0.5) ---
# Node2Vec (p=1.0, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=2
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:32<00:00,  1.08s/it, Loss=0.7858, Best=0.7858]
# Node2Vec (p=1.0, q=0.5) training completed in 32.46 seconds
# Full pipeline completed in 32.47 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  33%|███▎      | 1/3 [00:42<01:24, 42.24s/it, Testing=vec_size=4]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=4
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:30<00:00,  1.01s/it, Loss=0.7605, Best=0.7604]
# Node2Vec (p=1.0, q=0.5) training completed in 30.34 seconds
# Full pipeline completed in 30.35 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  67%|██████▋   | 2/3 [01:25<00:42, 42.79s/it, Testing=vec_size=8]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=8
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:27<00:00,  1.09it/s, Loss=0.7417, Best=0.7417]
# Node2Vec (p=1.0, q=0.5) training completed in 27.58 seconds
# Full pipeline completed in 27.59 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search: 100%|██████████| 3/3 [02:12<00:00, 44.06s/it, Testing=vec_size=8]
# [Node2Vec (p=1.0, q=0.5)] Best embedding size: 2 with r2: 0.992
#
# === Experiment Summary ===
# Dataset: MHD
# Graph type: KNN with Threshold
# Unified parameters applied to both datasets
# Saved results to results-gpu/MHD/final_results.csv
# Best configurations comparison plot saved to results-gpu/MHD/best_R2_comparison.png
# Selected best configurations for each method (based on R2):
#
# GradientBoosting:
#   Raw: R2=0.9937, R²=0.9937
#   DeepWalk: R2=0.9931, R²=0.9931
#   Node2Vec: p=0.5, q=1.0, R2=0.9937, R²=0.9937
#
# RandomForest:
#   Raw: R2=0.9932, R²=0.9932
#   DeepWalk: R2=0.9918, R²=0.9918
#   Node2Vec: p=1.0, q=0.5, R2=0.9928, R²=0.9928
# Best configurations comparison plot saved to results-gpu/MHD/best_RMSE_comparison.png
# Selected best configurations for each method (based on RMSE):
#
# GradientBoosting:
#   Raw: RMSE=426.6804, R²=0.9937
#   DeepWalk: RMSE=446.2839, R²=0.9931
#   Node2Vec: p=0.5, q=1.0, RMSE=425.8953, R²=0.9937
#
# RandomForest:
#   Raw: RMSE=442.5751, R²=0.9932
#   DeepWalk: RMSE=487.1038, R²=0.9918
#   Node2Vec: p=1.0, q=0.5, RMSE=456.3929, R²=0.9928
# Best configurations comparison plot saved to results-gpu/MHD/best_MSE_log_comparison.png
# Selected best configurations for each method (based on MSE_log):
#
# GradientBoosting:
#   Raw: MSE_log=0.0040, R²=0.9937
#   DeepWalk: MSE_log=0.0031, R²=0.9931
#   Node2Vec: p=0.5, q=1.0, MSE_log=0.0037, R²=0.9937
#
# RandomForest:
#   Raw: MSE_log=0.0016, R²=0.9932
#   DeepWalk: MSE_log=0.0018, R²=0.9918
#   Node2Vec: p=0.5, q=0.5, MSE_log=0.0017, R²=0.9926
# CPU times: total: 19min 37s
# Wall time: 9min 57s

# %%
# %%time
# %run main_pyg.py --dataset CA --num-walks 3 --walk-length 10 --p 2 --q 1 --embedding_sizes 2 5 --quiet

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method hybrid --embedding-sizes 2 4 16

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 5 --walk-length 15 --p 2 --q 1 --embedding_sizes 2 5 --quiet

# %%
# from utils_pyg import compare_models
# compare_models("CA", 'R2')
# compare_models("CA", 'RMSE')
# compare_models("CA", 'MSE_log')
# compare_models("MHD", 'R2') 
# compare_models("MHD", 'RMSE')
# compare_models("MHD", 'MSE_log')
