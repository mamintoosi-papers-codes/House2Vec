# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --graph-method threshold --embedding-sizes  2 4 8
# batch_size=4096
# Out:
# Loading dataset: CA
# KNN with Threshold graph construction completed in 0.70 seconds
# PyG Graph: 20433 nodes, 204330 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Loading baseline results from file...
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 80/80 [02:15<00:00,  1.70s/it, Loss=0.9894, Best=0.9894]
# Node2Vec (p=0.5, q=0.5) training completed in 135.86 seconds
# Full pipeline completed in 135.87 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [02:47<05:34, 167.42s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 80/80 [02:20<00:00,  1.75s/it, Loss=0.9152, Best=0.9152]
# Node2Vec (p=0.5, q=0.5) training completed in 140.32 seconds
# Full pipeline completed in 140.33 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  67%|██████▋   | 2/3 [05:46<02:54, 174.20s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=8
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 80/80 [02:24<00:00,  1.80s/it, Loss=0.8595, Best=0.8595]
# Node2Vec (p=0.5, q=0.5) training completed in 144.34 seconds
# Full pipeline completed in 144.35 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search: 100%|██████████| 3/3 [09:02<00:00, 180.83s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=0.5)] Best embedding size: 2 with r2: 0.779
#
# --- Strategy: dfs_local ---
# Parameters: p=0.5, q=1.0
# Testing Node2Vec (p=0.5, q=1.0) ---
# Node2Vec (p=0.5, q=1.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=2
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 80/80 [02:37<00:00,  1.97s/it, Loss=0.9900, Best=0.9900]
# Node2Vec (p=0.5, q=1.0) training completed in 157.35 seconds
# Full pipeline completed in 157.36 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  33%|███▎      | 1/3 [03:09<06:18, 189.09s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=4
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 80/80 [02:39<00:00,  1.99s/it, Loss=0.9155, Best=0.9155]
# Node2Vec (p=0.5, q=1.0) training completed in 159.39 seconds
# Full pipeline completed in 159.40 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  67%|██████▋   | 2/3 [06:26<03:14, 194.21s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=8
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 80/80 [02:46<00:00,  2.08s/it, Loss=0.8596, Best=0.8596]
# Node2Vec (p=0.5, q=1.0) training completed in 166.64 seconds
# Full pipeline completed in 166.64 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search: 100%|██████████| 3/3 [10:05<00:00, 201.75s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=1.0)] Best embedding size: 8 with r2: 0.778
#
# --- Strategy: deepwalk ---
# Parameters: p=1.0, q=1.0
# Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 80/80 [02:09<00:00,  1.62s/it, Loss=0.9878, Best=0.9878]
# DeepWalk training completed in 129.37 seconds
# Full pipeline completed in 129.38 seconds
# DeepWalk Grid Search:  33%|███▎      | 1/3 [02:41<05:22, 161.13s/it, Testing=vec_size=4]
# Training DeepWalk with vector_size=4
# DeepWalk Training: 100%|██████████| 80/80 [02:12<00:00,  1.65s/it, Loss=0.9148, Best=0.9148]
# DeepWalk training completed in 132.16 seconds
# Full pipeline completed in 132.17 seconds
# DeepWalk Grid Search:  67%|██████▋   | 2/3 [05:31<02:46, 166.59s/it, Testing=vec_size=8]
# Training DeepWalk with vector_size=8
# DeepWalk Training: 100%|██████████| 80/80 [02:14<00:00,  1.69s/it, Loss=0.8596, Best=0.8596]
# DeepWalk training completed in 134.95 seconds
# Full pipeline completed in 134.96 seconds
# DeepWalk Grid Search: 100%|██████████| 3/3 [08:38<00:00, 172.86s/it, Testing=vec_size=8]
# [DeepWalk] Best embedding size: 2 with r2: 0.778
#
# --- Strategy: bfs_local ---
# Parameters: p=1.0, q=0.5
# Testing Node2Vec (p=1.0, q=0.5) ---
# Node2Vec (p=1.0, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=2
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 80/80 [02:19<00:00,  1.74s/it, Loss=0.9898, Best=0.9898]
# Node2Vec (p=1.0, q=0.5) training completed in 139.24 seconds
# Full pipeline completed in 139.25 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  33%|███▎      | 1/3 [02:51<05:42, 171.07s/it, Testing=vec_size=4]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=4
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 80/80 [02:21<00:00,  1.76s/it, Loss=0.9150, Best=0.9150]
# Node2Vec (p=1.0, q=0.5) training completed in 141.07 seconds
# Full pipeline completed in 141.07 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  67%|██████▋   | 2/3 [05:51<02:56, 176.30s/it, Testing=vec_size=8]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=8
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 80/80 [02:24<00:00,  1.81s/it, Loss=0.8601, Best=0.8601]
# Node2Vec (p=1.0, q=0.5) training completed in 145.05 seconds
# Full pipeline completed in 145.06 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search: 100%|██████████| 3/3 [09:08<00:00, 182.73s/it, Testing=vec_size=8]
# [Node2Vec (p=1.0, q=0.5)] Best embedding size: 8 with r2: 0.779
#
# === Experiment Summary ===
# Dataset: CA
# Graph type: KNN with Threshold
# Unified parameters applied to both datasets
# Saved results to results-gpu/CA/final_results.csv
# Best configurations comparison plot saved to results-gpu/CA/best_R2_comparison.png
# Selected best configurations for each method (based on R2):
#
# GradientBoosting:
#   Raw: R2=0.7894, R²=0.7894
#   DeepWalk: R2=0.7903, R²=0.7903
#   Node2Vec: p=0.5, q=1.0, R2=0.7912, R²=0.7912
#
# RandomForest:
#   Raw: R2=0.8392, R²=0.8392
#   DeepWalk: R2=0.8380, R²=0.8380
#   Node2Vec: p=0.5, q=0.5, R2=0.8360, R²=0.8360
# Best configurations comparison plot saved to results-gpu/CA/best_RMSE_comparison.png
# Selected best configurations for each method (based on RMSE):
#
# GradientBoosting:
#   Raw: RMSE=53889.3508, R²=0.7894
#   DeepWalk: RMSE=53764.2524, R²=0.7903
#   Node2Vec: p=0.5, q=1.0, RMSE=53656.1790, R²=0.7912
#
# RandomForest:
#   Raw: RMSE=47090.1269, R²=0.8392
#   DeepWalk: RMSE=47258.9776, R²=0.8380
#   Node2Vec: p=0.5, q=1.0, RMSE=47546.6386, R²=0.8360
# Best configurations comparison plot saved to results-gpu/CA/best_MSE_log_comparison.png
# Selected best configurations for each method (based on MSE_log):
#
# GradientBoosting:
#   Raw: MSE_log=0.0126, R²=0.7894
#   DeepWalk: MSE_log=0.0126, R²=0.7903
#   Node2Vec: p=0.5, q=1.0, MSE_log=0.0126, R²=0.7912
#
# RandomForest:
#   Raw: MSE_log=0.0095, R²=0.8392
#   DeepWalk: MSE_log=0.0095, R²=0.8380
#   Node2Vec: p=0.5, q=1.0, MSE_log=0.0096, R²=0.8360
# CPU times: total: 1h 31min 27s
# Wall time: 40min 19s

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method threshold --embedding-sizes  2 4 8

# batch_size=4096
# Out:
# Loading dataset: MHD
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File D:\git\mamintoosi-papers-codes\House2Vec\main_pyg.py:240
#     237 parser.add_argument("--quiet", action="store_true", help="Reduce output verbosity")
#     238 args = parser.parse_args()
# --> 240 run_experiments_pyg(
#     241     args.dataset,
#     242     embedding_sizes=args.embedding_sizes,
#     243     graph_method=args.graph_method,
#     244     quiet=args.quiet
#     245 )
#
# File D:\git\mamintoosi-papers-codes\House2Vec\main_pyg.py:100, in run_experiments_pyg(dataset_name, embedding_sizes, graph_method, quiet)
#      98     graph_type = "KNN with Threshold"
#      99 elif graph_method == "hybrid":
# --> 100     pyg_data = create_hybrid_graph(
#     101         df, numeric_features, binary_features,
#     102         k=optimized_params['k'],
#     103         threshold=optimized_params['threshold'],
#     104         dataset_name=dataset_name
#     105     )
#     106     graph_type = "Hybrid"
#     107 else:  # "knn"
#
# File D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:264, in create_hybrid_graph(df, numeric_features, binary_features, k, threshold, scale_numeric, dataset_name)
#     262 threshold_nn = NearestNeighbors(radius=threshold, metric="euclidean")
#     263 threshold_nn.fit(X_geo)
# --> 264 threshold_distances, threshold_indices = threshold_nn.radius_neighbors(X_geo)
#     266 edges = set()  # Use set to avoid duplicates
#     268 # Add KNN connections
#
# File c:\Users\m.amintoosi\.conda\envs\pth-gpu\lib\site-packages\sklearn\neighbors\_base.py:1277, in RadiusNeighborsMixin.radius_neighbors(self, X, radius, return_distance, sort_results)
#    1275 n_jobs = effective_n_jobs(self.n_jobs)
#    1276 delayed_query = delayed(self._tree.query_radius)
# -> 1277 chunked_results = Parallel(n_jobs, prefer="threads")(
#    1278     delayed_query(X[s], radius, return_distance, sort_results=sort_results)
#    1279     for s in gen_even_slices(X.shape[0], n_jobs)
#    1280 )
#    1281 if return_distance:
#    1282     neigh_ind, neigh_dist = tuple(zip(*chunked_results))
#
# File c:\Users\m.amintoosi\.conda\envs\pth-gpu\lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\m.amintoosi\.conda\envs\pth-gpu\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\m.amintoosi\.conda\envs\pth-gpu\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\m.amintoosi\.conda\envs\pth-gpu\lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File sklearn\\neighbors\\_binary_tree.pxi:1431, in sklearn.neighbors._kd_tree.BinaryTree64.query_radius()
#
# File sklearn\\neighbors\\_binary_tree.pxi:1384, in sklearn.neighbors._kd_tree.BinaryTree64.query_radius()
#
# MemoryError:
# CPU times: total: 43min 55s
# Wall time: 4h 41min 25s
