# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --num-walks 10 --walk-length 10 --p 2 --q 2 --embedding_sizes 2 5 10 20
# Out:
# Loading dataset: CA
# Graph construction completed in 0.63 seconds
# PyG Graph: 20433 nodes, 204330 edges
#
# === Running Baseline Models ===
#
# === Running Node2Vec Grid Search (includes DeepWalk) ===
#
# --- Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:30<00:00,  1.02s/it, Loss=0.9983, Best=0.9983]
# DeepWalk training completed in 30.73 seconds
# Full pipeline completed in 30.74 seconds
# DeepWalk Grid Search:  25%|██▌       | 1/4 [01:55<05:47, 115.92s/it, Testing=vec_size=5]
# Training DeepWalk with vector_size=5
# DeepWalk Training: 100%|██████████| 30/30 [00:29<00:00,  1.02it/s, Loss=0.8966, Best=0.8965]
# DeepWalk training completed in 29.32 seconds
# Full pipeline completed in 29.32 seconds
# DeepWalk Grid Search:  50%|█████     | 2/4 [04:19<04:24, 132.17s/it, Testing=vec_size=10]
# Training DeepWalk with vector_size=10
# DeepWalk Training: 100%|██████████| 30/30 [00:28<00:00,  1.05it/s, Loss=0.8388, Best=0.8388]
# DeepWalk training completed in 28.58 seconds
# Full pipeline completed in 28.58 seconds
# DeepWalk Grid Search:  75%|███████▌  | 3/4 [07:32<02:39, 159.75s/it, Testing=vec_size=20]
# Training DeepWalk with vector_size=20
# DeepWalk Training: 100%|██████████| 30/30 [00:28<00:00,  1.07it/s, Loss=0.7961, Best=0.7960]
# DeepWalk training completed in 28.16 seconds
# Full pipeline completed in 28.16 seconds
# DeepWalk Grid Search: 100%|██████████| 4/4 [12:22<00:00, 185.62s/it, Testing=vec_size=20]
# [DeepWalk] Best embedding size: 5 with r2: 0.818
#
# --- Testing Node2Vec (p=1, q=2) ---
# Node2Vec (p=1, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1, q=2) with vector_size=2
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it, Loss=1.0054, Best=1.0054]
# Node2Vec (p=1, q=2) training completed in 34.84 seconds
# Full pipeline completed in 34.84 seconds
# Node2Vec (p=1, q=2) Grid Search:  25%|██▌       | 1/4 [01:59<05:59, 119.72s/it, Testing=vec_size=5]
# Training Node2Vec (p=1, q=2) with vector_size=5
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:31<00:00,  1.06s/it, Loss=0.9008, Best=0.9000]
# Node2Vec (p=1, q=2) training completed in 31.81 seconds
# Full pipeline completed in 31.81 seconds
# Node2Vec (p=1, q=2) Grid Search:  50%|█████     | 2/4 [04:26<04:31, 135.67s/it, Testing=vec_size=10]
# Training Node2Vec (p=1, q=2) with vector_size=10
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:30<00:00,  1.03s/it, Loss=0.8406, Best=0.8406]
# Node2Vec (p=1, q=2) training completed in 30.82 seconds
# Full pipeline completed in 30.82 seconds
# Node2Vec (p=1, q=2) Grid Search:  75%|███████▌  | 3/4 [07:42<02:42, 162.98s/it, Testing=vec_size=20]
# Training Node2Vec (p=1, q=2) with vector_size=20
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:30<00:00,  1.02s/it, Loss=0.7976, Best=0.7975]
# Node2Vec (p=1, q=2) training completed in 30.59 seconds
# Full pipeline completed in 30.61 seconds
# Node2Vec (p=1, q=2) Grid Search: 100%|██████████| 4/4 [12:37<00:00, 189.39s/it, Testing=vec_size=20]
# [Node2Vec (p=1, q=2)] Best embedding size: 5 with r2: 0.820
#
# --- Testing Node2Vec (p=2, q=1) ---
# Node2Vec (p=2, q=1) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=1) with vector_size=2
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:34<00:00,  1.13s/it, Loss=0.9983, Best=0.9983]
# Node2Vec (p=2, q=1) training completed in 34.05 seconds
# Full pipeline completed in 34.07 seconds
# Node2Vec (p=2, q=1) Grid Search:  25%|██▌       | 1/4 [01:58<05:55, 118.48s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=1) with vector_size=5
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:31<00:00,  1.03s/it, Loss=0.8967, Best=0.8966]
# Node2Vec (p=2, q=1) training completed in 31.02 seconds
# Full pipeline completed in 31.02 seconds
# Node2Vec (p=2, q=1) Grid Search:  50%|█████     | 2/4 [04:23<04:27, 133.84s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=1) with vector_size=10
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:29<00:00,  1.00it/s, Loss=0.8385, Best=0.8385]
# Node2Vec (p=2, q=1) training completed in 30.01 seconds
# Full pipeline completed in 30.02 seconds
# Node2Vec (p=2, q=1) Grid Search:  75%|███████▌  | 3/4 [07:36<02:41, 161.14s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=1) with vector_size=20
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:29<00:00,  1.00it/s, Loss=0.7960, Best=0.7960]
# Node2Vec (p=2, q=1) training completed in 29.92 seconds
# Full pipeline completed in 29.93 seconds
# Node2Vec (p=2, q=1) Grid Search: 100%|██████████| 4/4 [12:30<00:00, 187.50s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=1)] Best embedding size: 5 with r2: 0.819
#
# --- Testing Node2Vec (p=2, q=2) ---
# Node2Vec (p=2, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=2) with vector_size=2
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it, Loss=1.0045, Best=1.0038]
# Node2Vec (p=2, q=2) training completed in 34.81 seconds
# Full pipeline completed in 34.82 seconds
# Node2Vec (p=2, q=2) Grid Search:  25%|██▌       | 1/4 [02:02<06:07, 122.43s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=2) with vector_size=5
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:31<00:00,  1.06s/it, Loss=0.9001, Best=0.8998]
# Node2Vec (p=2, q=2) training completed in 31.95 seconds
# Full pipeline completed in 31.95 seconds
# Node2Vec (p=2, q=2) Grid Search:  50%|█████     | 2/4 [04:34<04:39, 139.96s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=2) with vector_size=10
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:32<00:00,  1.08s/it, Loss=0.8408, Best=0.8408]
# Node2Vec (p=2, q=2) training completed in 32.44 seconds
# Full pipeline completed in 32.45 seconds
# Node2Vec (p=2, q=2) Grid Search:  75%|███████▌  | 3/4 [07:56<02:48, 168.27s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=2) with vector_size=20
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:31<00:00,  1.04s/it, Loss=0.7975, Best=0.7974]
# Node2Vec (p=2, q=2) training completed in 31.08 seconds
# Full pipeline completed in 31.10 seconds
# Node2Vec (p=2, q=2) Grid Search: 100%|██████████| 4/4 [12:58<00:00, 194.61s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=2)] Best embedding size: 5 with r2: 0.818
#
# === Experiment Summary ===
# Saved results to results-gpu/CA/final_results.csv
# Total experiment time: 3205.78 seconds
# Timing breakdown saved to results-gpu/CA/experiment_timing.csv
# CPU times: total: 51min 37s
# Wall time: 53min 36s

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 50 --walk-length 15 --p 3 --q 3 --embedding_sizes 2 5 10 20
# Out:
# Loading dataset: MHD
# Graph construction completed in 2.46 seconds
# PyG Graph: 10000 nodes, 85959 edges
#
# === Running Baseline Models ===
#
# === Running Node2Vec Grid Search (includes DeepWalk) ===
#
# --- Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:35<00:00,  1.17s/it, Loss=0.7689, Best=0.7689]
# DeepWalk training completed in 35.33 seconds
# Full pipeline completed in 35.34 seconds
# DeepWalk Grid Search:  25%|██▌       | 1/4 [01:05<03:16, 65.61s/it, Testing=vec_size=5]
# Training DeepWalk with vector_size=5
# DeepWalk Training: 100%|██████████| 30/30 [00:33<00:00,  1.12s/it, Loss=0.7445, Best=0.7445]
# DeepWalk training completed in 33.72 seconds
# Full pipeline completed in 33.72 seconds
# DeepWalk Grid Search:  50%|█████     | 2/4 [02:22<02:24, 72.48s/it, Testing=vec_size=10]
# Training DeepWalk with vector_size=10
# DeepWalk Training: 100%|██████████| 30/30 [00:31<00:00,  1.06s/it, Loss=0.7302, Best=0.7302]
# DeepWalk training completed in 31.88 seconds
# Full pipeline completed in 31.88 seconds
# DeepWalk Grid Search:  75%|███████▌  | 3/4 [04:00<01:24, 84.05s/it, Testing=vec_size=20]
# Training DeepWalk with vector_size=20
# DeepWalk Training: 100%|██████████| 30/30 [00:30<00:00,  1.03s/it, Loss=0.7204, Best=0.7204]
# DeepWalk training completed in 30.89 seconds
# Full pipeline completed in 30.90 seconds
# DeepWalk Grid Search: 100%|██████████| 4/4 [06:22<00:00, 95.53s/it, Testing=vec_size=20]
# [DeepWalk] Best embedding size: 2 with r2: 0.819
#
# --- Testing Node2Vec (p=1, q=2) ---
# Node2Vec (p=1, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1, q=2) with vector_size=2
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:36<00:00,  1.21s/it, Loss=0.7702, Best=0.7702]
# Node2Vec (p=1, q=2) training completed in 36.18 seconds
# Full pipeline completed in 36.19 seconds
# Node2Vec (p=1, q=2) Grid Search:  25%|██▌       | 1/4 [01:06<03:19, 66.61s/it, Testing=vec_size=5]
# Training Node2Vec (p=1, q=2) with vector_size=5
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:35<00:00,  1.20s/it, Loss=0.7452, Best=0.7452]
# Node2Vec (p=1, q=2) training completed in 35.93 seconds
# Full pipeline completed in 35.93 seconds
# Node2Vec (p=1, q=2) Grid Search:  50%|█████     | 2/4 [02:26<02:28, 74.41s/it, Testing=vec_size=10]
# Training Node2Vec (p=1, q=2) with vector_size=10
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:34<00:00,  1.14s/it, Loss=0.7309, Best=0.7309]
# Node2Vec (p=1, q=2) training completed in 34.32 seconds
# Full pipeline completed in 34.33 seconds
# Node2Vec (p=1, q=2) Grid Search:  75%|███████▌  | 3/4 [04:07<01:26, 86.42s/it, Testing=vec_size=20]
# Training Node2Vec (p=1, q=2) with vector_size=20
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:33<00:00,  1.11s/it, Loss=0.7202, Best=0.7202]
# Node2Vec (p=1, q=2) training completed in 33.45 seconds
# Full pipeline completed in 33.45 seconds
# Node2Vec (p=1, q=2) Grid Search: 100%|██████████| 4/4 [06:30<00:00, 97.54s/it, Testing=vec_size=20]
# [Node2Vec (p=1, q=2)] Best embedding size: 2 with r2: 0.820
#
# --- Testing Node2Vec (p=1, q=3) ---
# Node2Vec (p=1, q=3) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1, q=3) with vector_size=2
# Node2Vec (p=1, q=3) Training: 100%|██████████| 30/30 [00:36<00:00,  1.21s/it, Loss=0.7717, Best=0.7717]
# Node2Vec (p=1, q=3) training completed in 36.29 seconds
# Full pipeline completed in 36.30 seconds
# Node2Vec (p=1, q=3) Grid Search:  25%|██▌       | 1/4 [01:06<03:20, 66.72s/it, Testing=vec_size=5]
# Training Node2Vec (p=1, q=3) with vector_size=5
# Node2Vec (p=1, q=3) Training: 100%|██████████| 30/30 [00:35<00:00,  1.20s/it, Loss=0.7452, Best=0.7452]
# Node2Vec (p=1, q=3) training completed in 35.94 seconds
# Full pipeline completed in 35.95 seconds
# Node2Vec (p=1, q=3) Grid Search:  50%|█████     | 2/4 [02:26<02:28, 74.45s/it, Testing=vec_size=10]
# Training Node2Vec (p=1, q=3) with vector_size=10
# Node2Vec (p=1, q=3) Training: 100%|██████████| 30/30 [00:34<00:00,  1.15s/it, Loss=0.7310, Best=0.7309]
# Node2Vec (p=1, q=3) training completed in 34.42 seconds
# Full pipeline completed in 34.42 seconds
# Node2Vec (p=1, q=3) Grid Search:  75%|███████▌  | 3/4 [04:06<01:26, 86.27s/it, Testing=vec_size=20]
# Training Node2Vec (p=1, q=3) with vector_size=20
# Node2Vec (p=1, q=3) Training: 100%|██████████| 30/30 [00:33<00:00,  1.11s/it, Loss=0.7207, Best=0.7207]
# Node2Vec (p=1, q=3) training completed in 33.18 seconds
# Full pipeline completed in 33.18 seconds
# Node2Vec (p=1, q=3) Grid Search: 100%|██████████| 4/4 [06:33<00:00, 98.34s/it, Testing=vec_size=20]
# [Node2Vec (p=1, q=3)] Best embedding size: 2 with r2: 0.819
#
# --- Testing Node2Vec (p=2, q=1) ---
# Node2Vec (p=2, q=1) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=1) with vector_size=2
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:36<00:00,  1.21s/it, Loss=0.7689, Best=0.7689]
# Node2Vec (p=2, q=1) training completed in 36.41 seconds
# Full pipeline completed in 36.41 seconds
# Node2Vec (p=2, q=1) Grid Search:  25%|██▌       | 1/4 [01:07<03:21, 67.30s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=1) with vector_size=5
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:36<00:00,  1.23s/it, Loss=0.7441, Best=0.7441]
# Node2Vec (p=2, q=1) training completed in 36.84 seconds
# Full pipeline completed in 36.84 seconds
# Node2Vec (p=2, q=1) Grid Search:  50%|█████     | 2/4 [02:29<02:31, 75.77s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=1) with vector_size=10
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:35<00:00,  1.17s/it, Loss=0.7304, Best=0.7304]
# Node2Vec (p=2, q=1) training completed in 35.12 seconds
# Full pipeline completed in 35.14 seconds
# Node2Vec (p=2, q=1) Grid Search:  75%|███████▌  | 3/4 [04:11<01:28, 88.17s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=1) with vector_size=20
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:34<00:00,  1.14s/it, Loss=0.7200, Best=0.7200]
# Node2Vec (p=2, q=1) training completed in 34.14 seconds
# Full pipeline completed in 34.15 seconds
# Node2Vec (p=2, q=1) Grid Search: 100%|██████████| 4/4 [06:39<00:00, 99.96s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=1)] Best embedding size: 2 with r2: 0.822
#
# --- Testing Node2Vec (p=2, q=2) ---
# Node2Vec (p=2, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=2) with vector_size=2
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:37<00:00,  1.25s/it, Loss=0.7700, Best=0.7699]
# Node2Vec (p=2, q=2) training completed in 37.38 seconds
# Full pipeline completed in 37.39 seconds
# Node2Vec (p=2, q=2) Grid Search:  25%|██▌       | 1/4 [01:08<03:26, 68.75s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=2) with vector_size=5
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:37<00:00,  1.24s/it, Loss=0.7445, Best=0.7445]
# Node2Vec (p=2, q=2) training completed in 37.13 seconds
# Full pipeline completed in 37.13 seconds
# Node2Vec (p=2, q=2) Grid Search:  50%|█████     | 2/4 [02:30<02:32, 76.50s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=2) with vector_size=10
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:33<00:00,  1.13s/it, Loss=0.7307, Best=0.7307]
# Node2Vec (p=2, q=2) training completed in 34.01 seconds
# Full pipeline completed in 34.01 seconds
# Node2Vec (p=2, q=2) Grid Search:  75%|███████▌  | 3/4 [04:10<01:27, 87.34s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=2) with vector_size=20
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:33<00:00,  1.11s/it, Loss=0.7204, Best=0.7204]
# Node2Vec (p=2, q=2) training completed in 33.24 seconds
# Full pipeline completed in 33.25 seconds
# Node2Vec (p=2, q=2) Grid Search: 100%|██████████| 4/4 [06:34<00:00, 98.51s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=2)] Best embedding size: 2 with r2: 0.823
#
# --- Testing Node2Vec (p=2, q=3) ---
# Node2Vec (p=2, q=3) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=3) with vector_size=2
# Node2Vec (p=2, q=3) Training: 100%|██████████| 30/30 [00:37<00:00,  1.26s/it, Loss=0.7713, Best=0.7713]
# Node2Vec (p=2, q=3) training completed in 37.83 seconds
# Full pipeline completed in 37.84 seconds
# Node2Vec (p=2, q=3) Grid Search:  25%|██▌       | 1/4 [01:08<03:26, 68.80s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=3) with vector_size=5
# Node2Vec (p=2, q=3) Training: 100%|██████████| 30/30 [00:37<00:00,  1.23s/it, Loss=0.7455, Best=0.7455]
# Node2Vec (p=2, q=3) training completed in 37.05 seconds
# Full pipeline completed in 37.06 seconds
# Node2Vec (p=2, q=3) Grid Search:  50%|█████     | 2/4 [02:30<02:33, 76.65s/it, Testing=vec_size=10]
# Training Node2Vec (p=2, q=3) with vector_size=10
# Node2Vec (p=2, q=3) Training: 100%|██████████| 30/30 [00:35<00:00,  1.17s/it, Loss=0.7309, Best=0.7309]
# Node2Vec (p=2, q=3) training completed in 35.18 seconds
# Full pipeline completed in 35.20 seconds
# Node2Vec (p=2, q=3) Grid Search:  75%|███████▌  | 3/4 [04:14<01:28, 88.71s/it, Testing=vec_size=20]
# Training Node2Vec (p=2, q=3) with vector_size=20
# Node2Vec (p=2, q=3) Training: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it, Loss=0.7203, Best=0.7203]
# Node2Vec (p=2, q=3) training completed in 34.69 seconds
# Full pipeline completed in 34.70 seconds
# Node2Vec (p=2, q=3) Grid Search: 100%|██████████| 4/4 [06:42<00:00, 100.53s/it, Testing=vec_size=20]
# [Node2Vec (p=2, q=3)] Best embedding size: 5 with r2: 0.820
#
# --- Testing Node2Vec (p=3, q=1) ---
# Node2Vec (p=3, q=1) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=3, q=1) with vector_size=2
# Node2Vec (p=3, q=1) Training: 100%|██████████| 30/30 [00:37<00:00,  1.24s/it, Loss=0.7690, Best=0.7690]
# Node2Vec (p=3, q=1) training completed in 37.29 seconds
# Full pipeline completed in 37.30 seconds
# Node2Vec (p=3, q=1) Grid Search:  25%|██▌       | 1/4 [01:08<03:26, 68.83s/it, Testing=vec_size=5]
# Training Node2Vec (p=3, q=1) with vector_size=5
# Node2Vec (p=3, q=1) Training: 100%|██████████| 30/30 [00:37<00:00,  1.24s/it, Loss=0.7443, Best=0.7443]
# Node2Vec (p=3, q=1) training completed in 37.28 seconds
# Full pipeline completed in 37.29 seconds
# Node2Vec (p=3, q=1) Grid Search:  50%|█████     | 2/4 [02:31<02:33, 76.99s/it, Testing=vec_size=10]
# Training Node2Vec (p=3, q=1) with vector_size=10
# Node2Vec (p=3, q=1) Training: 100%|██████████| 30/30 [00:35<00:00,  1.17s/it, Loss=0.7306, Best=0.7306]
# Node2Vec (p=3, q=1) training completed in 35.26 seconds
# Full pipeline completed in 35.27 seconds
# Node2Vec (p=3, q=1) Grid Search:  75%|███████▌  | 3/4 [04:13<01:28, 88.37s/it, Testing=vec_size=20]
# Training Node2Vec (p=3, q=1) with vector_size=20
# Node2Vec (p=3, q=1) Training: 100%|██████████| 30/30 [00:32<00:00,  1.10s/it, Loss=0.7197, Best=0.7197]
# Node2Vec (p=3, q=1) training completed in 32.88 seconds
# Full pipeline completed in 32.89 seconds
# Node2Vec (p=3, q=1) Grid Search: 100%|██████████| 4/4 [06:38<00:00, 99.75s/it, Testing=vec_size=20]
# [Node2Vec (p=3, q=1)] Best embedding size: 5 with r2: 0.823
#
# --- Testing Node2Vec (p=3, q=2) ---
# Node2Vec (p=3, q=2) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=3, q=2) with vector_size=2
# Node2Vec (p=3, q=2) Training: 100%|██████████| 30/30 [00:36<00:00,  1.23s/it, Loss=0.7708, Best=0.7708]
# Node2Vec (p=3, q=2) training completed in 36.95 seconds
# Full pipeline completed in 36.95 seconds
# Node2Vec (p=3, q=2) Grid Search:  25%|██▌       | 1/4 [01:08<03:24, 68.19s/it, Testing=vec_size=5]
# Training Node2Vec (p=3, q=2) with vector_size=5
# Node2Vec (p=3, q=2) Training: 100%|██████████| 30/30 [00:37<00:00,  1.25s/it, Loss=0.7449, Best=0.7449]
# Node2Vec (p=3, q=2) training completed in 37.37 seconds
# Full pipeline completed in 37.37 seconds
# Node2Vec (p=3, q=2) Grid Search:  50%|█████     | 2/4 [02:30<02:33, 76.62s/it, Testing=vec_size=10]
# Training Node2Vec (p=3, q=2) with vector_size=10
# Node2Vec (p=3, q=2) Training: 100%|██████████| 30/30 [00:35<00:00,  1.18s/it, Loss=0.7304, Best=0.7304]
# Node2Vec (p=3, q=2) training completed in 35.30 seconds
# Full pipeline completed in 35.31 seconds
# Node2Vec (p=3, q=2) Grid Search:  75%|███████▌  | 3/4 [04:13<01:28, 88.48s/it, Testing=vec_size=20]
# Training Node2Vec (p=3, q=2) with vector_size=20
# Node2Vec (p=3, q=2) Training: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it, Loss=0.7202, Best=0.7202]
# Node2Vec (p=3, q=2) training completed in 34.97 seconds
# Full pipeline completed in 34.97 seconds
# Node2Vec (p=3, q=2) Grid Search: 100%|██████████| 4/4 [06:42<00:00, 100.57s/it, Testing=vec_size=20]
# [Node2Vec (p=3, q=2)] Best embedding size: 10 with r2: 0.818
#
# --- Testing Node2Vec (p=3, q=3) ---
# Node2Vec (p=3, q=3) Grid Search:   0%|          | 0/4 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=3, q=3) with vector_size=2
# Node2Vec (p=3, q=3) Training: 100%|██████████| 30/30 [00:38<00:00,  1.27s/it, Loss=0.7703, Best=0.7703]
# Node2Vec (p=3, q=3) training completed in 38.04 seconds
# Full pipeline completed in 38.05 seconds
# Node2Vec (p=3, q=3) Grid Search:  25%|██▌       | 1/4 [01:09<03:28, 69.39s/it, Testing=vec_size=5]
# Training Node2Vec (p=3, q=3) with vector_size=5
# Node2Vec (p=3, q=3) Training: 100%|██████████| 30/30 [00:36<00:00,  1.21s/it, Loss=0.7452, Best=0.7452]
# Node2Vec (p=3, q=3) training completed in 36.41 seconds
# Full pipeline completed in 36.41 seconds
# Node2Vec (p=3, q=3) Grid Search:  50%|█████     | 2/4 [02:29<02:31, 75.74s/it, Testing=vec_size=10]
# Training Node2Vec (p=3, q=3) with vector_size=10
# Node2Vec (p=3, q=3) Training: 100%|██████████| 30/30 [00:34<00:00,  1.15s/it, Loss=0.7309, Best=0.7308]
# Node2Vec (p=3, q=3) training completed in 34.38 seconds
# Full pipeline completed in 34.39 seconds
# Node2Vec (p=3, q=3) Grid Search:  75%|███████▌  | 3/4 [04:10<01:27, 87.03s/it, Testing=vec_size=20]
# Training Node2Vec (p=3, q=3) with vector_size=20
# Node2Vec (p=3, q=3) Training: 100%|██████████| 30/30 [00:34<00:00,  1.15s/it, Loss=0.7206, Best=0.7206]
# Node2Vec (p=3, q=3) training completed in 34.66 seconds
# Full pipeline completed in 34.66 seconds
# Node2Vec (p=3, q=3) Grid Search: 100%|██████████| 4/4 [06:36<00:00, 99.04s/it, Testing=vec_size=20]
# [Node2Vec (p=3, q=3)] Best embedding size: 2 with r2: 0.821
#
# === Experiment Summary ===
# Saved results to results-gpu/MHD/final_results.csv
# Total experiment time: 3697.67 seconds
# Timing breakdown saved to results-gpu/MHD/experiment_timing.csv
# CPU times: total: 1h 34min 4s
# Wall time: 1h 1min 37s

# %%
# from utils_pyg import compare_models
# compare_models("CA", 'R2')
# compare_models("CA", 'RMSE')
# compare_models("CA", 'MSE_log')
# compare_models("MHD", 'R2') 
# compare_models("MHD", 'RMSE')
# compare_models("MHD", 'MSE_log')
