# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --graph-method threshold --embedding-sizes 2 4 8
# Out:
# Loading dataset: CA
# KNN with Threshold graph construction completed in 0.84 seconds
# PyG Graph: 20433 nodes, 204330 edges
#
# === Running Baseline Models ===
# Loading baseline results from file...
#
# === Running Node2Vec Grid Search (includes DeepWalk) ===
#
# --- Testing Node2Vec (p=0.5, q=2.0) ---
# Node2Vec (p=0.5, q=2.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=2.0) with vector_size=2
# Node2Vec (p=0.5, q=2.0) Training: 100%|██████████| 30/30 [01:14<00:00,  2.49s/it, Loss=1.0045, Best=1.0045]
# Node2Vec (p=0.5, q=2.0) Grid Search:  33%|███▎      | 1/3 [01:15<02:30, 75.06s/it, Testing=vec_size=4]
# Node2Vec (p=0.5, q=2.0) training completed in 74.88 seconds
# Full pipeline completed in 74.89 seconds
# Training Node2Vec (p=0.5, q=2.0) with vector_size=4
# Node2Vec (p=0.5, q=2.0) Training: 100%|██████████| 30/30 [01:08<00:00,  2.28s/it, Loss=0.9216, Best=0.9216]
# Node2Vec (p=0.5, q=2.0) Grid Search:  67%|██████▋   | 2/3 [02:23<01:11, 71.17s/it, Testing=vec_size=8]
# Node2Vec (p=0.5, q=2.0) training completed in 68.34 seconds
# Full pipeline completed in 68.35 seconds
# Training Node2Vec (p=0.5, q=2.0) with vector_size=8
# Node2Vec (p=0.5, q=2.0) Training: 100%|██████████| 30/30 [01:04<00:00,  2.15s/it, Loss=0.8557, Best=0.8557]
# Node2Vec (p=0.5, q=2.0) Grid Search: 100%|██████████| 3/3 [03:28<00:00, 69.41s/it, Testing=vec_size=8]
# Node2Vec (p=0.5, q=2.0) training completed in 64.57 seconds
# Full pipeline completed in 64.58 seconds
#
# [Node2Vec (p=0.5, q=2.0)] Best embedding size: 8 with r2: 0.653
#
# --- Testing Node2Vec (p=0.5, q=1.0) ---
# Node2Vec (p=0.5, q=1.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=2
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [01:09<00:00,  2.32s/it, Loss=0.9976, Best=0.9976]
# Node2Vec (p=0.5, q=1.0) Grid Search:  33%|███▎      | 1/3 [01:09<02:19, 69.84s/it, Testing=vec_size=4]
# Node2Vec (p=0.5, q=1.0) training completed in 69.73 seconds
# Full pipeline completed in 69.74 seconds
# Training Node2Vec (p=0.5, q=1.0) with vector_size=4
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [01:06<00:00,  2.21s/it, Loss=0.9169, Best=0.9169]
# Node2Vec (p=0.5, q=1.0) training completed in 66.48 seconds
# Full pipeline completed in 66.49 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  67%|██████▋   | 2/3 [02:16<01:08, 68.05s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=8
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [01:01<00:00,  2.05s/it, Loss=0.8519, Best=0.8519]
# Node2Vec (p=0.5, q=1.0) training completed in 61.58 seconds
# Full pipeline completed in 61.58 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search: 100%|██████████| 3/3 [03:18<00:00, 66.20s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=1.0)] Best embedding size: 8 with r2: 0.650
#
# --- Testing Node2Vec (p=1.0, q=2.0) ---
# Node2Vec (p=1.0, q=2.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1.0, q=2.0) with vector_size=2
# Node2Vec (p=1.0, q=2.0) Training: 100%|██████████| 30/30 [01:07<00:00,  2.25s/it, Loss=1.0027, Best=1.0027]
# Node2Vec (p=1.0, q=2.0) Grid Search:  33%|███▎      | 1/3 [01:07<02:15, 67.58s/it, Testing=vec_size=4]
# Node2Vec (p=1.0, q=2.0) training completed in 67.43 seconds
# Full pipeline completed in 67.43 seconds
# Training Node2Vec (p=1.0, q=2.0) with vector_size=4
# Node2Vec (p=1.0, q=2.0) Training: 100%|██████████| 30/30 [01:01<00:00,  2.05s/it, Loss=0.9197, Best=0.9197]
# Node2Vec (p=1.0, q=2.0) Grid Search:  67%|██████▋   | 2/3 [02:09<01:04, 64.11s/it, Testing=vec_size=8]
# Node2Vec (p=1.0, q=2.0) training completed in 61.53 seconds
# Full pipeline completed in 61.54 seconds
# Training Node2Vec (p=1.0, q=2.0) with vector_size=8
# Node2Vec (p=1.0, q=2.0) Training: 100%|██████████| 30/30 [00:58<00:00,  1.96s/it, Loss=0.8546, Best=0.8546]
# Node2Vec (p=1.0, q=2.0) Grid Search: 100%|██████████| 3/3 [03:08<00:00, 62.72s/it, Testing=vec_size=8]
# Node2Vec (p=1.0, q=2.0) training completed in 58.77 seconds
# Full pipeline completed in 58.77 seconds
#
# [Node2Vec (p=1.0, q=2.0)] Best embedding size: 8 with r2: 0.650
#
# --- Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:58<00:00,  1.95s/it, Loss=0.9971, Best=0.9970]
# DeepWalk Grid Search:  33%|███▎      | 1/3 [00:58<01:57, 58.73s/it, Testing=vec_size=4]
# DeepWalk training completed in 58.59 seconds
# Full pipeline completed in 58.60 seconds
# Training DeepWalk with vector_size=4
# DeepWalk Training: 100%|██████████| 30/30 [00:54<00:00,  1.80s/it, Loss=0.9156, Best=0.9156]
# DeepWalk Grid Search:  67%|██████▋   | 2/3 [01:52<00:56, 56.09s/it, Testing=vec_size=8]
# DeepWalk training completed in 54.16 seconds
# Full pipeline completed in 54.17 seconds
# Training DeepWalk with vector_size=8
# DeepWalk Training: 100%|██████████| 30/30 [00:50<00:00,  1.69s/it, Loss=0.8519, Best=0.8519]
# DeepWalk Grid Search: 100%|██████████| 3/3 [02:43<00:00, 54.62s/it, Testing=vec_size=8]
# DeepWalk training completed in 50.73 seconds
# Full pipeline completed in 50.74 seconds
#
# [DeepWalk] Best embedding size: 8 with r2: 0.653
#
# === Experiment Summary ===
# Graph type: KNN with Threshold
# Optimized parameters: {'num_walks': 50, 'walk_length': 10, 'p': 0.5, 'q': 2.0, 'epochs': 30, 'k': 10, 'threshold': 4000}
# Saved results to results-gpu/CA/final_results.csv
# Total experiment time: 999.98 seconds
# Timing breakdown saved to results-gpu/CA/experiment_timing.csv
# Best configurations comparison plot saved to results-gpu/CA/best_R2_comparison.png
# Selected best configurations for each method (based on R2):
#
# GradientBoosting:
#   Raw: R2=0.7894, R²=0.7894
#   DeepWalk: R2=0.7930, R²=0.7930
#   Node2Vec: p=1.0, q=2.0, R2=0.7961, R²=0.7961
#
# RandomForest:
#   Raw: R2=0.8392, R²=0.8392
#   DeepWalk: R2=0.8404, R²=0.8404
#   Node2Vec: p=1.0, q=2.0, R2=0.8435, R²=0.8435
# Best configurations comparison plot saved to results-gpu/CA/best_RMSE_comparison.png
# Selected best configurations for each method (based on RMSE):
#
# GradientBoosting:
#   Raw: RMSE=53889.3508, R²=0.7894
#   DeepWalk: RMSE=53416.9329, R²=0.7930
#   Node2Vec: p=1.0, q=2.0, RMSE=53018.7171, R²=0.7961
#
# RandomForest:
#   Raw: RMSE=47090.1269, R²=0.8392
#   DeepWalk: RMSE=46911.6660, R²=0.8404
#   Node2Vec: p=1.0, q=2.0, RMSE=46454.7340, R²=0.8435
# Best configurations comparison plot saved to results-gpu/CA/best_MSE_log_comparison.png
# Selected best configurations for each method (based on MSE_log):
#
# GradientBoosting:
#   Raw: MSE_log=0.0126, R²=0.7894
#   DeepWalk: MSE_log=0.0125, R²=0.7930
#   Node2Vec: p=1.0, q=2.0, MSE_log=0.0124, R²=0.7961
#
# RandomForest:
#   Raw: MSE_log=0.0095, R²=0.8392
#   DeepWalk: MSE_log=0.0093, R²=0.8404
#   Node2Vec: p=1.0, q=2.0, MSE_log=0.0093, R²=0.8435
# CPU times: total: 35min 37s
# Wall time: 17min 18s

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method threshold --embedding-sizes  4
# Out:
# Loading dataset: MHD
# KNN with Threshold graph construction completed in 5.43 seconds
# PyG Graph: 20000 nodes, 171697 edges
#
# === Running Baseline Models ===
# Running baseline models...
# Baseline results saved to results-gpu/MHD/baseline_results.csv
#
# === Running Node2Vec Grid Search (includes DeepWalk) ===
#
# --- Testing Node2Vec (p=0.5, q=2.0) ---
# Node2Vec (p=0.5, q=2.0) Grid Search:   0%|          | 0/1 [00:00<?, ?it/s, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=2.0) with vector_size=4
# Node2Vec (p=0.5, q=2.0) Training: 100%|██████████| 30/30 [01:03<00:00,  2.11s/it, Loss=0.7496, Best=0.7496]
# Node2Vec (p=0.5, q=2.0) training completed in 63.41 seconds
# Full pipeline completed in 63.43 seconds
# Node2Vec (p=0.5, q=2.0) Grid Search: 100%|██████████| 1/1 [01:29<00:00, 89.90s/it, Testing=vec_size=4]
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:564: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   master_df = pd.concat([master_df, new_results], ignore_index=True)
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:583: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   timing_master_df = pd.concat([timing_master_df, new_timing], ignore_index=True)
# [Node2Vec (p=0.5, q=2.0)] Best embedding size: 4 with r2: 0.995
#
# --- Testing Node2Vec (p=0.5, q=1.0) ---
# Node2Vec (p=0.5, q=1.0) Grid Search:   0%|          | 0/1 [00:00<?, ?it/s, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=4
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [01:02<00:00,  2.10s/it, Loss=0.7486, Best=0.7486]
# Node2Vec (p=0.5, q=1.0) training completed in 62.93 seconds
# Full pipeline completed in 62.94 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search: 100%|██████████| 1/1 [01:29<00:00, 89.65s/it, Testing=vec_size=4]
# [Node2Vec (p=0.5, q=1.0)] Best embedding size: 4 with r2: 0.995
#
# --- Testing Node2Vec (p=1.0, q=2.0) ---
# Node2Vec (p=1.0, q=2.0) Grid Search:   0%|          | 0/1 [00:00<?, ?it/s, Testing=vec_size=4]
# Training Node2Vec (p=1.0, q=2.0) with vector_size=4
# Node2Vec (p=1.0, q=2.0) Training: 100%|██████████| 30/30 [00:57<00:00,  1.92s/it, Loss=0.7492, Best=0.7492]
# Node2Vec (p=1.0, q=2.0) training completed in 57.77 seconds
# Full pipeline completed in 57.79 seconds
# Node2Vec (p=1.0, q=2.0) Grid Search: 100%|██████████| 1/1 [01:24<00:00, 84.65s/it, Testing=vec_size=4]
# [Node2Vec (p=1.0, q=2.0)] Best embedding size: 4 with r2: 0.995
#
# --- Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/1 [00:00<?, ?it/s, Testing=vec_size=4]
# Training DeepWalk with vector_size=4
# DeepWalk Training: 100%|██████████| 30/30 [00:52<00:00,  1.74s/it, Loss=0.7491, Best=0.7491]
# DeepWalk training completed in 52.20 seconds
# Full pipeline completed in 52.21 seconds
# DeepWalk Grid Search: 100%|██████████| 1/1 [01:18<00:00, 78.48s/it, Testing=vec_size=4]
# [DeepWalk] Best embedding size: 4 with r2: 0.995
#
# === Experiment Summary ===
# Graph type: KNN with Threshold
# Optimized parameters: {'num_walks': 50, 'walk_length': 10, 'p': 0.5, 'q': 2.0, 'epochs': 30, 'k': 10, 'threshold': 100}
# Saved results to results-gpu/MHD/final_results.csv
# Total experiment time: 491.12 seconds
# Timing breakdown saved to results-gpu/MHD/experiment_timing.csv
# Best configurations comparison plot saved to results-gpu/MHD/best_R2_comparison.png
# Selected best configurations for each method (based on R2):
#
# GradientBoosting:
#   Raw: R2=0.9943, R²=0.9943
#   DeepWalk: R2=0.9943, R²=0.9943
#   Node2Vec: p=0.5, q=2.0, R2=0.9942, R²=0.9942
#
# RandomForest:
#   Raw: R2=0.9958, R²=0.9958
#   DeepWalk: R2=0.9954, R²=0.9954
#   Node2Vec: p=0.5, q=2.0, R2=0.9957, R²=0.9957
# Best configurations comparison plot saved to results-gpu/MHD/best_RMSE_comparison.png
# Selected best configurations for each method (based on RMSE):
#
# GradientBoosting:
#   Raw: RMSE=411.0207, R²=0.9943
#   DeepWalk: RMSE=411.7491, R²=0.9943
#   Node2Vec: p=0.5, q=2.0, RMSE=413.7355, R²=0.9942
#
# RandomForest:
#   Raw: RMSE=351.5528, R²=0.9958
#   DeepWalk: RMSE=370.2223, R²=0.9954
#   Node2Vec: p=0.5, q=2.0, RMSE=355.9609, R²=0.9957
# Best configurations comparison plot saved to results-gpu/MHD/best_MSE_log_comparison.png
# Selected best configurations for each method (based on MSE_log):
#
# GradientBoosting:
#   Raw: MSE_log=0.1626, R²=0.9943
#   DeepWalk: MSE_log=0.1626, R²=0.9943
#   Node2Vec: p=0.5, q=2.0, MSE_log=0.1624, R²=0.9942
#
# RandomForest:
#   Raw: MSE_log=0.0004, R²=0.9958
#   DeepWalk: MSE_log=0.0006, R²=0.9954
#   Node2Vec: p=0.5, q=2.0, MSE_log=0.0006, R²=0.9957
# CPU times: total: 14min 18s
# Wall time: 8min 23s

# %%
# %%time
# %run main_pyg.py --dataset CA --num-walks 3 --walk-length 10 --p 2 --q 1 --embedding_sizes 2 5 --quiet
# Out:
# CPU times: total: 2min 53s
# Wall time: 3min 10s

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method hybrid --embedding-sizes 2 4 16

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 5 --walk-length 15 --p 2 --q 1 --embedding_sizes 2 5 --quiet
# Out:
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:449: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   master_df = pd.concat([master_df, new_results], ignore_index=True)
# D:\git\mamintoosi-papers-codes\House2Vec\utils_pyg.py:468: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   timing_master_df = pd.concat([timing_master_df, new_timing], ignore_index=True)
# === Experiment Summary ===
# Saved results to results-gpu/MHD/final_results.csv
# Total experiment time: 121.80 seconds
# Timing breakdown saved to results-gpu/MHD/experiment_timing.csv
# CPU times: total: 1min 59s
# Wall time: 2min 13s

# %%
# from utils_pyg import compare_models
# compare_models("CA", 'R2')
# compare_models("CA", 'RMSE')
# compare_models("CA", 'MSE_log')
# compare_models("MHD", 'R2') 
# compare_models("MHD", 'RMSE')
# compare_models("MHD", 'MSE_log')
