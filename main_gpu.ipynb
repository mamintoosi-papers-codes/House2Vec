# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --graph-method threshold --embedding-sizes 2 4 8
# Out:
# Loading dataset: CA
# KNN with Threshold graph construction completed in 1.00 seconds
# PyG Graph: 20433 nodes, 204330 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Loading baseline results from file...
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:26<00:00,  1.14it/s, Loss=1.0005, Best=1.0005]
# Node2Vec (p=0.5, q=0.5) training completed in 26.31 seconds
# Full pipeline completed in 26.31 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [00:58<01:57, 58.96s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:24<00:00,  1.22it/s, Loss=0.9167, Best=0.9167]
# Node2Vec (p=0.5, q=0.5) training completed in 24.53 seconds
# Full pipeline completed in 24.53 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  67%|██████▋   | 2/3 [02:01<01:01, 61.04s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=8
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:23<00:00,  1.26it/s, Loss=0.8535, Best=0.8535]
# Node2Vec (p=0.5, q=0.5) training completed in 23.78 seconds
# Full pipeline completed in 23.78 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search: 100%|██████████| 3/3 [03:16<00:00, 65.45s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=0.5)] Best embedding size: 8 with r2: 0.780
#
# --- Strategy: dfs_local ---
# Parameters: p=0.5, q=1.0
# Testing Node2Vec (p=0.5, q=1.0) ---
# Node2Vec (p=0.5, q=1.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=2
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:27<00:00,  1.07it/s, Loss=1.0012, Best=1.0012]
# Node2Vec (p=0.5, q=1.0) training completed in 28.01 seconds
# Full pipeline completed in 28.02 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  33%|███▎      | 1/3 [00:59<01:58, 59.45s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=4
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:29<00:00,  1.02it/s, Loss=0.9174, Best=0.9174]
# Node2Vec (p=0.5, q=1.0) training completed in 29.50 seconds
# Full pipeline completed in 29.51 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  67%|██████▋   | 2/3 [02:08<01:05, 65.28s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=8
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:29<00:00,  1.01it/s, Loss=0.8537, Best=0.8537]
# Node2Vec (p=0.5, q=1.0) training completed in 29.68 seconds
# Full pipeline completed in 29.69 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search: 100%|██████████| 3/3 [03:31<00:00, 70.62s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=1.0)] Best embedding size: 4 with r2: 0.780
#
# --- Strategy: deepwalk ---
# Parameters: p=1.0, q=1.0
# Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:24<00:00,  1.21it/s, Loss=0.9981, Best=0.9981]
# DeepWalk training completed in 24.73 seconds
# Full pipeline completed in 24.74 seconds
# DeepWalk Grid Search:  33%|███▎      | 1/3 [00:57<01:55, 57.79s/it, Testing=vec_size=4]
# Training DeepWalk with vector_size=4
# DeepWalk Training: 100%|██████████| 30/30 [00:25<00:00,  1.20it/s, Loss=0.9174, Best=0.9174]
# DeepWalk training completed in 25.13 seconds
# Full pipeline completed in 25.14 seconds
# DeepWalk Grid Search:  67%|██████▋   | 2/3 [02:03<01:02, 62.29s/it, Testing=vec_size=8]
# Training DeepWalk with vector_size=8
# DeepWalk Training: 100%|██████████| 30/30 [00:24<00:00,  1.23it/s, Loss=0.8532, Best=0.8532]
# DeepWalk training completed in 24.34 seconds
# Full pipeline completed in 24.35 seconds
# DeepWalk Grid Search: 100%|██████████| 3/3 [03:20<00:00, 66.75s/it, Testing=vec_size=8]
# [DeepWalk] Best embedding size: 4 with r2: 0.779
#
# --- Strategy: bfs_local ---
# Parameters: p=1.0, q=0.5
# Testing Node2Vec (p=1.0, q=0.5) ---
# Node2Vec (p=1.0, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=2
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:26<00:00,  1.15it/s, Loss=0.9989, Best=0.9989]
# Node2Vec (p=1.0, q=0.5) training completed in 26.05 seconds
# Full pipeline completed in 26.06 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  33%|███▎      | 1/3 [00:58<01:56, 58.46s/it, Testing=vec_size=4]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=4
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:25<00:00,  1.15it/s, Loss=0.9175, Best=0.9175]
# Node2Vec (p=1.0, q=0.5) training completed in 26.02 seconds
# Full pipeline completed in 26.03 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  67%|██████▋   | 2/3 [02:04<01:02, 62.83s/it, Testing=vec_size=8]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=8
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:26<00:00,  1.15it/s, Loss=0.8533, Best=0.8533]
# Node2Vec (p=1.0, q=0.5) training completed in 26.07 seconds
# Full pipeline completed in 26.08 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search: 100%|██████████| 3/3 [03:23<00:00, 67.81s/it, Testing=vec_size=8]
# [Node2Vec (p=1.0, q=0.5)] Best embedding size: 4 with r2: 0.779
#
# === Experiment Summary ===
# Dataset: CA
# Graph type: KNN with Threshold
# Unified parameters applied to both datasets
# Saved results to results-gpu/CA/final_results.csv
# Best configurations comparison plot saved to results-gpu/CA/best_R2_comparison.png
# Selected best configurations for each method (based on R2):
#
# GradientBoosting:
#   Raw: R2=0.7894, R²=0.7894
#   DeepWalk: R2=0.7922, R²=0.7922
#   Node2Vec: p=0.5, q=0.5, R2=0.7927, R²=0.7927
#
# RandomForest:
#   Raw: R2=0.8392, R²=0.8392
#   DeepWalk: R2=0.8390, R²=0.8390
#   Node2Vec: p=0.5, q=1.0, R2=0.8376, R²=0.8376
# Best configurations comparison plot saved to results-gpu/CA/best_RMSE_comparison.png
# Selected best configurations for each method (based on RMSE):
#
# GradientBoosting:
#   Raw: RMSE=53889.3508, R²=0.7894
#   DeepWalk: RMSE=53522.7104, R²=0.7922
#   Node2Vec: p=0.5, q=0.5, RMSE=53457.3866, R²=0.7927
#
# RandomForest:
#   Raw: RMSE=47090.1269, R²=0.8392
#   DeepWalk: RMSE=47113.7997, R²=0.8390
#   Node2Vec: p=0.5, q=1.0, RMSE=47314.2163, R²=0.8376
# Best configurations comparison plot saved to results-gpu/CA/best_MSE_log_comparison.png
# Selected best configurations for each method (based on MSE_log):
#
# GradientBoosting:
#   Raw: MSE_log=0.0126, R²=0.7894
#   DeepWalk: MSE_log=0.0125, R²=0.7922
#   Node2Vec: p=0.5, q=1.0, MSE_log=0.0124, R²=0.7925
#
# RandomForest:
#   Raw: MSE_log=0.0095, R²=0.8392
#   DeepWalk: MSE_log=0.0094, R²=0.8390
#   Node2Vec: p=1.0, q=0.5, MSE_log=0.0094, R²=0.8376
# CPU times: total: 24min 55s
# Wall time: 16min 49s

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method threshold --embedding-sizes  2 4 8
# Out:
# Loading dataset: MHD
# KNN with Threshold graph construction completed in 3.25 seconds
# PyG Graph: 10000 nodes, 85959 edges
# Testing 4 unified walk strategies
#
# === Running Baseline Models ===
# Loading baseline results from file...
#
# === Testing Unified Walk Strategies ===
#
# --- Strategy: dfs_balanced ---
# Parameters: p=0.5, q=0.5
# Testing Node2Vec (p=0.5, q=0.5) ---
# Node2Vec (p=0.5, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=2
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:14<00:00,  2.01it/s, Loss=0.7942, Best=0.7942]
# Node2Vec (p=0.5, q=0.5) training completed in 15.14 seconds
# Full pipeline completed in 15.15 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  33%|███▎      | 1/3 [00:25<00:51, 25.59s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=4
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:14<00:00,  2.07it/s, Loss=0.7697, Best=0.7697]
# Node2Vec (p=0.5, q=0.5) training completed in 14.49 seconds
# Full pipeline completed in 14.50 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search:  67%|██████▋   | 2/3 [00:53<00:26, 26.68s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=0.5) with vector_size=8
# Node2Vec (p=0.5, q=0.5) Training: 100%|██████████| 30/30 [00:13<00:00,  2.23it/s, Loss=0.7529, Best=0.7529]
# Node2Vec (p=0.5, q=0.5) training completed in 13.49 seconds
# Full pipeline completed in 13.50 seconds
# Node2Vec (p=0.5, q=0.5) Grid Search: 100%|██████████| 3/3 [01:26<00:00, 28.97s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=0.5)] Best embedding size: 2 with r2: 0.992
#
# --- Strategy: dfs_local ---
# Parameters: p=0.5, q=1.0
# Testing Node2Vec (p=0.5, q=1.0) ---
# Node2Vec (p=0.5, q=1.0) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=2
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:15<00:00,  1.93it/s, Loss=0.7954, Best=0.7954]
# Node2Vec (p=0.5, q=1.0) training completed in 15.60 seconds
# Full pipeline completed in 15.61 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  33%|███▎      | 1/3 [00:25<00:51, 25.88s/it, Testing=vec_size=4]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=4
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:15<00:00,  1.89it/s, Loss=0.7701, Best=0.7701]
# Node2Vec (p=0.5, q=1.0) training completed in 15.92 seconds
# Full pipeline completed in 15.93 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search:  67%|██████▋   | 2/3 [00:55<00:27, 27.89s/it, Testing=vec_size=8]
# Training Node2Vec (p=0.5, q=1.0) with vector_size=8
# Node2Vec (p=0.5, q=1.0) Training: 100%|██████████| 30/30 [00:15<00:00,  1.95it/s, Loss=0.7535, Best=0.7535]
# Node2Vec (p=0.5, q=1.0) training completed in 15.42 seconds
# Full pipeline completed in 15.42 seconds
# Node2Vec (p=0.5, q=1.0) Grid Search: 100%|██████████| 3/3 [01:30<00:00, 30.15s/it, Testing=vec_size=8]
# [Node2Vec (p=0.5, q=1.0)] Best embedding size: 4 with r2: 0.992
#
# --- Strategy: deepwalk ---
# Parameters: p=1.0, q=1.0
# Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:12<00:00,  2.33it/s, Loss=0.7956, Best=0.7956]
# DeepWalk training completed in 12.91 seconds
# Full pipeline completed in 12.92 seconds
# DeepWalk Grid Search:  33%|███▎      | 1/3 [00:22<00:45, 22.92s/it, Testing=vec_size=4]
# Training DeepWalk with vector_size=4
# DeepWalk Training: 100%|██████████| 30/30 [00:12<00:00,  2.33it/s, Loss=0.7706, Best=0.7706]
# DeepWalk training completed in 12.91 seconds
# Full pipeline completed in 12.92 seconds
# DeepWalk Grid Search:  67%|██████▋   | 2/3 [00:49<00:24, 24.90s/it, Testing=vec_size=8]
# Training DeepWalk with vector_size=8
# DeepWalk Training: 100%|██████████| 30/30 [00:12<00:00,  2.33it/s, Loss=0.7535, Best=0.7535]
# DeepWalk training completed in 12.87 seconds
# Full pipeline completed in 12.88 seconds
# DeepWalk Grid Search: 100%|██████████| 3/3 [01:22<00:00, 27.34s/it, Testing=vec_size=8]
# [DeepWalk] Best embedding size: 4 with r2: 0.992
#
# --- Strategy: bfs_local ---
# Parameters: p=1.0, q=0.5
# Testing Node2Vec (p=1.0, q=0.5) ---
# Node2Vec (p=1.0, q=0.5) Grid Search:   0%|          | 0/3 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=2
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:14<00:00,  2.07it/s, Loss=0.7953, Best=0.7953]
# Node2Vec (p=1.0, q=0.5) training completed in 14.51 seconds
# Full pipeline completed in 14.52 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  33%|███▎      | 1/3 [00:24<00:49, 24.52s/it, Testing=vec_size=4]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=4
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:14<00:00,  2.11it/s, Loss=0.7703, Best=0.7703]
# Node2Vec (p=1.0, q=0.5) training completed in 14.21 seconds
# Full pipeline completed in 14.22 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search:  67%|██████▋   | 2/3 [00:51<00:26, 26.24s/it, Testing=vec_size=8]
# Training Node2Vec (p=1.0, q=0.5) with vector_size=8
# Node2Vec (p=1.0, q=0.5) Training: 100%|██████████| 30/30 [00:14<00:00,  2.10it/s, Loss=0.7529, Best=0.7529]
# Node2Vec (p=1.0, q=0.5) training completed in 14.29 seconds
# Full pipeline completed in 14.30 seconds
# Node2Vec (p=1.0, q=0.5) Grid Search: 100%|██████████| 3/3 [01:26<00:00, 28.69s/it, Testing=vec_size=8]
# [Node2Vec (p=1.0, q=0.5)] Best embedding size: 4 with r2: 0.992
#
# === Experiment Summary ===
# Dataset: MHD
# Graph type: KNN with Threshold
# Unified parameters applied to both datasets
# Saved results to results-gpu/MHD/final_results.csv
# Best configurations comparison plot saved to results-gpu/MHD/best_R2_comparison.png
# Selected best configurations for each method (based on R2):
#
# GradientBoosting:
#   Raw: R2=0.9937, R²=0.9937
#   DeepWalk: R2=0.9940, R²=0.9940
#   Node2Vec: p=1.0, q=0.5, R2=0.9936, R²=0.9936
#
# RandomForest:
#   Raw: R2=0.9932, R²=0.9932
#   DeepWalk: R2=0.9924, R²=0.9924
#   Node2Vec: p=0.5, q=0.5, R2=0.9928, R²=0.9928
# Best configurations comparison plot saved to results-gpu/MHD/best_RMSE_comparison.png
# Selected best configurations for each method (based on RMSE):
#
# GradientBoosting:
#   Raw: RMSE=426.6804, R²=0.9937
#   DeepWalk: RMSE=417.0637, R²=0.9940
#   Node2Vec: p=1.0, q=0.5, RMSE=428.5244, R²=0.9936
#
# RandomForest:
#   Raw: RMSE=442.5751, R²=0.9932
#   DeepWalk: RMSE=466.2964, R²=0.9924
#   Node2Vec: p=0.5, q=0.5, RMSE=456.3987, R²=0.9928
# Best configurations comparison plot saved to results-gpu/MHD/best_MSE_log_comparison.png
# Selected best configurations for each method (based on MSE_log):
#
# GradientBoosting:
#   Raw: MSE_log=0.0040, R²=0.9937
#   DeepWalk: MSE_log=0.0035, R²=0.9940
#   Node2Vec: p=1.0, q=0.5, MSE_log=0.0035, R²=0.9936
#
# RandomForest:
#   Raw: MSE_log=0.0016, R²=0.9932
#   DeepWalk: MSE_log=0.0019, R²=0.9924
#   Node2Vec: p=1.0, q=0.5, MSE_log=0.0016, R²=0.9922
# CPU times: total: 11min 25s
# Wall time: 7min 21s

# %%
# %%time
# %run main_pyg.py --dataset CA --num-walks 3 --walk-length 10 --p 2 --q 1 --embedding_sizes 2 5 --quiet

# %%
# %%time
# %run main_pyg.py --dataset MHD --graph-method hybrid --embedding-sizes 2 4 16

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 5 --walk-length 15 --p 2 --q 1 --embedding_sizes 2 5 --quiet

# %%
# from utils_pyg import compare_models
# compare_models("CA", 'R2')
# compare_models("CA", 'RMSE')
# compare_models("CA", 'MSE_log')
# compare_models("MHD", 'R2') 
# compare_models("MHD", 'RMSE')
# compare_models("MHD", 'MSE_log')
