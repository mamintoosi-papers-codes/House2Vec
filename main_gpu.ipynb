# %% [markdown]
# # House2vec
#
# House2Vec is a Python repository for **house representation learning** using **graph-based embedding methods** (DeepWalk and Node2Vec).
# The goal is to enhance **house price prediction** by capturing **spatial relationships** among properties through network representation learning.

# %%
# %%time
# %run main_pyg.py --dataset CA --num-walks 10 --walk-length 10 --p 2 --q 2 --embedding_sizes 2 5 10 20
# Out:
# PyG Graph: 20433 nodes, 204330 edges
# [deepwalk] Evaluating embedding size: 2
# DeepWalk Epoch: 010, Loss: 0.9860
# DeepWalk Epoch: 020, Loss: 0.9811
# DeepWalk Epoch: 030, Loss: 0.9790
# [deepwalk] Evaluating embedding size: 5
# DeepWalk Epoch: 010, Loss: 0.8889
# DeepWalk Epoch: 020, Loss: 0.8845
# DeepWalk Epoch: 030, Loss: 0.8828
# [deepwalk] Best embedding size: 5 with r2: 0.821
# [node2vec] Evaluating embedding size: 2
# Node2Vec Epoch: 010, Loss: 0.9851
# Node2Vec Epoch: 020, Loss: 0.9803
# Node2Vec Epoch: 030, Loss: 0.9788
# [node2vec] Evaluating embedding size: 5
# Node2Vec Epoch: 010, Loss: 0.8887
# Node2Vec Epoch: 020, Loss: 0.8849
# Node2Vec Epoch: 030, Loss: 0.8832
# [node2vec] Best embedding size: 2 with r2: 0.818
# [node2vec] Evaluating embedding size: 2
# Node2Vec Epoch: 010, Loss: 0.9963
# Node2Vec Epoch: 020, Loss: 0.9897
# Node2Vec Epoch: 030, Loss: 0.9870
# [node2vec] Evaluating embedding size: 5
# Node2Vec Epoch: 010, Loss: 0.8941
# Node2Vec Epoch: 020, Loss: 0.8895
# Node2Vec Epoch: 030, Loss: 0.8880
# [node2vec] Best embedding size: 5 with r2: 0.819
# [node2vec] Evaluating embedding size: 2
# Node2Vec Epoch: 010, Loss: 0.9865
# Node2Vec Epoch: 020, Loss: 0.9815
# Node2Vec Epoch: 030, Loss: 0.9799
# [node2vec] Evaluating embedding size: 5
# Node2Vec Epoch: 010, Loss: 0.8884
# Node2Vec Epoch: 020, Loss: 0.8845
# Node2Vec Epoch: 030, Loss: 0.8829
# [node2vec] Best embedding size: 5 with r2: 0.819
# [node2vec] Evaluating embedding size: 2
# Node2Vec Epoch: 010, Loss: 0.9945
# Node2Vec Epoch: 020, Loss: 0.9881
# Node2Vec Epoch: 030, Loss: 0.9861
# [node2vec] Evaluating embedding size: 5
# Node2Vec Epoch: 010, Loss: 0.8933
# Node2Vec Epoch: 020, Loss: 0.8890
# Node2Vec Epoch: 030, Loss: 0.8874
# [node2vec] Best embedding size: 5 with r2: 0.820
# Saved results to results/CA/final_results_pyg.csv
# CPU times: total: 40min 23s
# Wall time: 29min 18s

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 3 --walk-length 10 --p 2 --q 2 --embedding_sizes 2 5
# Out:
# Loading dataset: MHD
# Graph construction completed in 0.65 seconds
# PyG Graph: 2000 nodes, 17325 edges
#
# === Running Baseline Models ===
#
# === Running Node2Vec Grid Search (includes DeepWalk) ===
#
# --- Testing DeepWalk ---
# DeepWalk Grid Search:   0%|          | 0/2 [00:00<?, ?it/s, Testing=vec_size=2]
# Training DeepWalk with vector_size=2
# DeepWalk Training: 100%|██████████| 30/30 [00:03<00:00,  8.77it/s, Loss=0.8419, Best=0.8419]
# DeepWalk training completed in 3.62 seconds
# Full pipeline completed in 3.62 seconds
# DeepWalk Grid Search:  50%|█████     | 1/2 [00:10<00:10, 10.10s/it, Testing=vec_size=5]
# Training DeepWalk with vector_size=5
# DeepWalk Training: 100%|██████████| 30/30 [00:03<00:00,  9.42it/s, Loss=0.8082, Best=0.8079]
# DeepWalk training completed in 3.19 seconds
# Full pipeline completed in 3.20 seconds
# DeepWalk Grid Search: 100%|██████████| 2/2 [00:21<00:00, 10.92s/it, Testing=vec_size=5]
# [DeepWalk] Best embedding size: 5 with r2: 0.710
#
# --- Testing Node2Vec (p=1, q=2) ---
# Node2Vec (p=1, q=2) Grid Search:   0%|          | 0/2 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=1, q=2) with vector_size=2
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:04<00:00,  7.40it/s, Loss=0.8453, Best=0.8453]
# Node2Vec (p=1, q=2) training completed in 4.07 seconds
# Full pipeline completed in 4.07 seconds
# Node2Vec (p=1, q=2) Grid Search:  50%|█████     | 1/2 [00:10<00:10, 10.34s/it, Testing=vec_size=5]
# Training Node2Vec (p=1, q=2) with vector_size=5
# Node2Vec (p=1, q=2) Training: 100%|██████████| 30/30 [00:03<00:00,  9.01it/s, Loss=0.8073, Best=0.8073]
# Node2Vec (p=1, q=2) training completed in 3.34 seconds
# Full pipeline completed in 3.35 seconds
# Node2Vec (p=1, q=2) Grid Search: 100%|██████████| 2/2 [00:21<00:00, 10.91s/it, Testing=vec_size=5]
# [Node2Vec (p=1, q=2)] Best embedding size: 2 with r2: 0.706
#
# --- Testing Node2Vec (p=2, q=1) ---
# Node2Vec (p=2, q=1) Grid Search:   0%|          | 0/2 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=1) with vector_size=2
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:03<00:00,  8.34it/s, Loss=0.8421, Best=0.8421]
# Node2Vec (p=2, q=1) training completed in 3.61 seconds
# Full pipeline completed in 3.61 seconds
# Node2Vec (p=2, q=1) Grid Search:  50%|█████     | 1/2 [00:09<00:09,  9.67s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=1) with vector_size=5
# Node2Vec (p=2, q=1) Training: 100%|██████████| 30/30 [00:03<00:00,  8.74it/s, Loss=0.8065, Best=0.8065]
# Node2Vec (p=2, q=1) training completed in 3.44 seconds
# Full pipeline completed in 3.44 seconds
# Node2Vec (p=2, q=1) Grid Search: 100%|██████████| 2/2 [00:21<00:00, 10.81s/it, Testing=vec_size=5]
# [Node2Vec (p=2, q=1)] Best embedding size: 5 with r2: 0.699
#
# --- Testing Node2Vec (p=2, q=2) ---
# Node2Vec (p=2, q=2) Grid Search:   0%|          | 0/2 [00:00<?, ?it/s, Testing=vec_size=2]
# Training Node2Vec (p=2, q=2) with vector_size=2
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:03<00:00,  8.26it/s, Loss=0.8417, Best=0.8417]
# Node2Vec (p=2, q=2) training completed in 3.64 seconds
# Full pipeline completed in 3.65 seconds
# Node2Vec (p=2, q=2) Grid Search:  50%|█████     | 1/2 [00:09<00:09,  9.71s/it, Testing=vec_size=5]
# Training Node2Vec (p=2, q=2) with vector_size=5
# Node2Vec (p=2, q=2) Training: 100%|██████████| 30/30 [00:03<00:00,  8.96it/s, Loss=0.8093, Best=0.8093]
# Node2Vec (p=2, q=2) training completed in 3.36 seconds
# Full pipeline completed in 3.36 seconds
# Node2Vec (p=2, q=2) Grid Search: 100%|██████████| 2/2 [00:21<00:00, 10.65s/it, Testing=vec_size=5]
# [Node2Vec (p=2, q=2)] Best embedding size: 2 with r2: 0.702
#
# === Experiment Summary ===
# Saved results to results-gpu/MHD/final_results.csv
# Total experiment time: 115.92 seconds
# Timing breakdown saved to results-gpu/MHD/experiment_timing.csv
# CPU times: total: 1min 59s
# Wall time: 2min 10s

# %%
# %%time
# %run main_pyg.py --dataset MHD --num-walks 20 --walk-length 15 --p 2 --q 2 --embedding_sizes 2 5 10 20

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter
import os

def compare_models(dataset_name, use_rmse=False, res_file_name="final_results.csv"):
    """
    Side-by-side comparison plots (R² and MSE_log or RMSE) for a dataset.
    - Highlights the single best model across all methods with a red star.
    - Adds dataset name to each subplot.
    - Applies y-axis limits to emphasize differences.
    - If use_rmse=True, plots RMSE in millions; otherwise plots MSE_log.
    """
    # Load results
    file_path = f"results-gpu/{dataset_name}/{res_file_name}"
    df = pd.read_csv(file_path)

    # Categorize models
    def categorize(model):
        if "DeepWalk" in model:
            return "DeepWalk"
        elif "Node2Vec" in model:
            return "Node2Vec"
        else:
            return "Raw"

    # df["Method"] = df["Model"].apply(categorize)
    # df["BaseModel"] = df["Model"].apply(lambda x: x.split(" ")[0])

    # Pivot to align bars by BaseModel for each Type
    order_types = ["Raw", "DeepWalk", "Node2Vec"]
    r2_pivot = df.pivot_table(index="BaseModel", columns="Method", values="R2", aggfunc="mean").reindex(columns=order_types)
    mselog_pivot = df.pivot_table(index="BaseModel", columns="Method", values="MSE_log", aggfunc="mean").reindex(columns=order_types)
    rmse_pivot = df.pivot_table(index="BaseModel", columns="Method", values="RMSE", aggfunc="mean").reindex(columns=order_types)

    # Base models for x-axis
    models = r2_pivot.index.tolist()
    x = np.arange(len(models))
    bar_width = 0.25

    fig, axs = plt.subplots(1, 2, figsize=(14, 6))

    # -------------------------------
    # Plot 1: R² comparison
    # -------------------------------
    all_r2_bars = []
    bar_positions = []
    for i, t in enumerate(order_types):
        vals = r2_pivot[t].values
        positions = x + i*bar_width - bar_width
        axs[0].bar(positions, vals, width=bar_width, label=t)
        all_r2_bars.extend(vals)
        bar_positions.extend(positions)

    # Highlight single best R² (max)
    best_idx = np.nanargmax(all_r2_bars)
    axs[0].scatter(bar_positions[best_idx], all_r2_bars[best_idx],
                   color="red", zorder=5, s=100, marker="*")

    axs[0].set_title("R² Score Comparison")
    axs[0].set_xticks(x)
    axs[0].set_xticklabels(models)#, rotation=45)
    axs[0].set_ylabel("R²")
    axs[0].legend()

    # y-axis limit
    r2_mean = np.nanmean(all_r2_bars)
    axs[0].set_ylim(0.6, 0.92)

    axs[0].text(0.5, 0.05, f"Dataset: {dataset_name}", transform=axs[0].transAxes,
                fontsize=10, ha="center", va="bottom",
                bbox=dict(boxstyle="round", fc="white", alpha=0.6))

    # -------------------------------
    # Plot 2: MSE_log or RMSE comparison
    # -------------------------------
    if use_rmse:
        metric_name = "RMSE"
        pivot = rmse_pivot
        # formatter
        def thousands(x, pos): return f"{x/1e3:.1f}K"
        def millions(x, pos): return f"{x/1e6:.1f}M"
        def billions(x, pos): return f"{x/1e9:.1f}B"

        if dataset_name == 'CA':
            axs[1].yaxis.set_major_formatter(FuncFormatter(thousands))
        else:
            axs[1].yaxis.set_major_formatter(FuncFormatter(billions))
    else:
        metric_name = "MSE (log-scale)"
        pivot = mselog_pivot

    all_metric_bars = []
    bar_positions_metric = []
    for i, t in enumerate(order_types):
        vals = pivot[t].values
        positions = x + i*bar_width - bar_width
        axs[1].bar(positions, vals, width=bar_width, label=t)
        all_metric_bars.extend(vals)
        bar_positions_metric.extend(positions)

    # Highlight single best (min) for RMSE or MSE_log
    best_idx = np.nanargmin(all_metric_bars)
    axs[1].scatter(bar_positions_metric[best_idx], all_metric_bars[best_idx],
                   color="red", zorder=5, s=100, marker="*")

    axs[1].set_title(f"{metric_name} Comparison")
    axs[1].set_xticks(x)
    axs[1].set_xticklabels(models)#, rotation=45)
    axs[1].set_ylabel(metric_name)
    axs[1].legend()

    # y-axis limit
    y_mean = np.nanmean(all_metric_bars)
    axs[1].set_ylim(y_mean * 0.7, y_mean * 1.4)

    axs[1].text(0.5, 0.05, f"Dataset: {dataset_name}", transform=axs[1].transAxes,
                fontsize=10, ha="center", va="bottom",
                bbox=dict(boxstyle="round", fc="white", alpha=0.6))

    plt.tight_layout()

    # Save figure
    out_path = f"results-gpu/{dataset_name}/model_comparison.png" if not use_rmse \
               else f"results-gpu/{dataset_name}/model_comparison_rmse.png"
    os.makedirs(f"results-gpu/{dataset_name}", exist_ok=True)
    plt.savefig(out_path, dpi=300)
    plt.show()
    print(f"Comparison plot saved to {out_path}")


# Example runs
# compare_models("CA", True, "final_results.csv")  # R² + RMSE (in millions)
compare_models("MHD", True, "final_results.csv")
# Out:
# Comparison plot saved to results-gpu/MHD/model_comparison_rmse.png
